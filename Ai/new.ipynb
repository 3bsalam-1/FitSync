# %% [markdown]
# #Data mining

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head(5)
# Out:
#    Meal_Id      \
# 0  meal_id1
# 1  meal_id2
# 2  meal_id3
# 3  meal_id4
# 4  meal_id5
#
#   Name                                                                            \
# 0  summer squash salad                           ...
# 1  chicken minced salad                          ...
# 2  sweet chilli almonds                          ...
# 3  tricolour salad                               ...
# 4  gluten-free christmas cake                    ...
#
#    catagory      \
# 0  salad
# 1  salad
# 2  chilli
# 3  salad
# 4  cake
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 9 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Non-Null Count  Dtype
# ...

# %%
df.columns = df.columns.str.strip()
newdf=df['Disease'].str.contains('diabeties')

# %%
df[newdf]
# Out:
#          Meal_Id                                               Name  \
# 0    meal_id1     summer squash salad                           ...
# 9    meal_id10    broccoli and almond soup                      ...
# 11   meal_id12    lemon honey glazed sous vide corn on the cob  ...
# 13   meal_id14    peach, raspberry and nuts smoothie            ...
# 15   meal_id16    almond and raw banana galawat                 ...
# ..           ...                                                ...
# 505  meal_id303   red rice                                      ...
# 506  meal_id304   rice                                          ...
# 509  meal_id307   bhurji- egg                                   ...
# 510  meal_id308   flattened rice / pohe                         ...
# 511  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# 0    salad         white balsamic vinegar, lemon juice, lemon rin...
# ...

# %%
n2 = (df['Disease'].str.contains('diabeties')) | (df['Disease'].str.contains('heart_disease'))

# %%
df[n2]
# Out:
#          Meal_Id                                               Name  \
# 0    meal_id1     summer squash salad                           ...
# 2    meal_id3     sweet chilli almonds                          ...
# 6    meal_id7     chocolate nero cookies                        ...
# 9    meal_id10    broccoli and almond soup                      ...
# 11   meal_id12    lemon honey glazed sous vide corn on the cob  ...
# ..           ...                                                ...
# 505  meal_id303   red rice                                      ...
# 506  meal_id304   rice                                          ...
# 509  meal_id307   bhurji- egg                                   ...
# 510  meal_id308   flattened rice / pohe                         ...
# 511  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# 0    salad         white balsamic vinegar, lemon juice, lemon rin...
# ...

# %%
df['Disease'].unique()
# Out:
# array(['obesity diabeties hypertension goitre                                                                                 ',
#        'anemia pregnancy hypertension rickets goitre kidney_disease obesity                                                   ',
#        'hypertension scurvy heart_disease goitre kidney_disease pregnancy                                                     ',
#        'obesity goitre hypertension                                                                                           ',
#        'goitre kidney_disease                                                                                                 ',
#        'goitre                                                                                                                ',
#        'hypertension heart_disease                                                                                            ',
# ...

# %%
n2 = (df['Disease'].str.contains('diabeties')) | (df['Disease'].str.contains('heart_disease')) | (df['Disease'].str.contains('hypertension'))

# %%
df1=df[n2]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 315 entries, 0 to 511
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Meal_Id      315 non-null    object
#  1   Name         315 non-null    object
#  2   catagory     315 non-null    object
#  3   description  315 non-null    object
#  4   Veg_Non      315 non-null    object
#  5   Nutrient     315 non-null    object
#  6   Disease      315 non-null    object
#  7   Diet         315 non-null    object
#  8   Price        315 non-null    int64
# dtypes: int64(1), object(8)
# memory usage: 24.6+ KB

# %%
df1=df1.reset_index()

# %%
df1.drop('index', inplace=True, axis=1)

# %%
df1.to_csv("final1.csv")

# %%
data = pd.read_csv('final2.csv', encoding = "cp1252")

# %%
data.reset_index
# Out:
# <bound method DataFrame.reset_index of      Unnamed: 0     Meal_Id                    Name catagory  \
# 0             0    meal_id1     summer squash salad    salad
# 1             1    meal_id2    chicken minced salad    salad
# 2             2    meal_id3    sweet chilli almonds   chilli
# 3             3    meal_id4         tricolour salad    salad
# 4             6    meal_id7  chocolate nero cookies   cookie
# ..          ...         ...                     ...      ...
# 310         506  meal_id304                    rice     rice
# 311         508  meal_id306            banana chips   banana
# 312         509  meal_id307             bhurji- egg      egg
# 313         510  meal_id308   flattened rice / pohe     rice
# 314         511  meal_id309             puffed rice     rice
#
#                                            description  Veg_Non  \
# 0    white balsamic vinegar, lemon juice, lemon rin...      veg
# ...

# %%
df1
# Out:
#          Meal_Id                                               Name  \
# 0    meal_id1     summer squash salad                           ...
# 1    meal_id2     chicken minced salad                          ...
# 2    meal_id3     sweet chilli almonds                          ...
# 3    meal_id4     tricolour salad                               ...
# 4    meal_id7     chocolate nero cookies                        ...
# ..           ...                                                ...
# 310  meal_id304   rice                                          ...
# 311  meal_id306   banana chips                                  ...
# 312  meal_id307   bhurji- egg                                   ...
# 313  meal_id308   flattened rice / pohe                         ...
# 314  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# 0    salad         white balsamic vinegar, lemon juice, lemon rin...
# ...

# %%
data.to_csv("final3.csv")

# %%
df = pd.read_csv('finaldata.csv')
df
# Out:
#            Meal_Id      \
# 0       0  meal_id1
# 1       1  meal_id2
# 2       2  meal_id3
# 3       3  meal_id4
# 4       6  meal_id7
# ..    ...          ...
# 310   506  meal_id304
# 311   508  meal_id306
# 312   509  meal_id307
# 313   510  meal_id308
# 314   511  meal_id309
#
#     Name                                                                            \
# 0    summer squash salad                           ...
# 1    chicken minced salad                          ...
# 2    sweet chilli almonds                          ...
# 3    tricolour salad                               ...
# 4    chocolate nero cookies                        ...
# ..                                                 ...
# 310  rice                                          ...
# 311  banana chips                                  ...
# 312  bhurji- egg                                   ...
# 313  flattened rice / pohe                         ...
# 314  puffed rice                                   ...
# ...

# %%
df.reset_index(drop=True)
# Out:
#            Meal_Id      \
# 0       0  meal_id1
# 1       1  meal_id2
# 2       2  meal_id3
# 3       3  meal_id4
# 4       6  meal_id7
# ..    ...          ...
# 310   506  meal_id304
# 311   508  meal_id306
# 312   509  meal_id307
# 313   510  meal_id308
# 314   511  meal_id309
#
#     Name                                                                            \
# 0    summer squash salad                           ...
# 1    chicken minced salad                          ...
# 2    sweet chilli almonds                          ...
# 3    tricolour salad                               ...
# 4    chocolate nero cookies                        ...
# ..                                                 ...
# 310  rice                                          ...
# 311  banana chips                                  ...
# 312  bhurji- egg                                   ...
# 313  flattened rice / pohe                         ...
# 314  puffed rice                                   ...
# ...

# %%
df.columns = df.columns.str.strip()
df['diabeties'] = df['Disease'].str.contains('diabeties')
df['heart_disease'] = df['Disease'].str.contains('heart_disease')
df['hypertension'] = df['Disease'].str.contains('hypertension')
df
# Out:
#               Meal_Id                                               Name  \
# 0      0  meal_id1     summer squash salad                           ...
# 1      1  meal_id2     chicken minced salad                          ...
# 2      2  meal_id3     sweet chilli almonds                          ...
# 3      3  meal_id4     tricolour salad                               ...
# 4      6  meal_id7     chocolate nero cookies                        ...
# ..   ...          ...                                                ...
# 310  506  meal_id304   rice                                          ...
# 311  508  meal_id306   banana chips                                  ...
# 312  509  meal_id307   bhurji- egg                                   ...
# 313  510  meal_id308   flattened rice / pohe                         ...
# 314  511  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Sample categorical data

# Create an instance of LabelEncoder
encoder = LabelEncoder()

# Fit and transform the data
df['diabeties'] = encoder.fit_transform(df['diabeties'])
df['heart_disease'] = encoder.fit_transform(df['heart_disease'])
df['hypertension'] = encoder.fit_transform(df['hypertension'])
df
# Out:
#               Meal_Id                                               Name  \
# 0      0  meal_id1     summer squash salad                           ...
# 1      1  meal_id2     chicken minced salad                          ...
# 2      2  meal_id3     sweet chilli almonds                          ...
# 3      3  meal_id4     tricolour salad                               ...
# 4      6  meal_id7     chocolate nero cookies                        ...
# ..   ...          ...                                                ...
# 310  506  meal_id304   rice                                          ...
# 311  508  meal_id306   banana chips                                  ...
# 312  509  meal_id307   bhurji- egg                                   ...
# 313  510  meal_id308   flattened rice / pohe                         ...
# 314  511  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# ...

# %%
df.drop('Disease', inplace=True, axis=1)
df.drop('Price', inplace=True, axis=1)

df
# Out:
#               Meal_Id                                               Name  \
# 0      0  meal_id1     summer squash salad                           ...
# 1      1  meal_id2     chicken minced salad                          ...
# 2      2  meal_id3     sweet chilli almonds                          ...
# 3      3  meal_id4     tricolour salad                               ...
# 4      6  meal_id7     chocolate nero cookies                        ...
# ..   ...          ...                                                ...
# 310  506  meal_id304   rice                                          ...
# 311  508  meal_id306   banana chips                                  ...
# 312  509  meal_id307   bhurji- egg                                   ...
# 313  510  meal_id308   flattened rice / pohe                         ...
# 314  511  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# ...

# %%
df
# Out:
#      Meal_Id      \
# 0    meal_id1
# 1    meal_id2
# 2    meal_id3
# 3    meal_id4
# 4    meal_id5
# ..           ...
# 507  meal_id305
# 508  meal_id306
# 509  meal_id307
# 510  meal_id308
# 511  meal_id309
#
#     Name                                                                            \
# 0    summer squash salad                           ...
# 1    chicken minced salad                          ...
# 2    sweet chilli almonds                          ...
# 3    tricolour salad                               ...
# 4    gluten-free christmas cake                    ...
# ..                                                 ...
# 507  sunga pork                                    ...
# 508  banana chips                                  ...
# 509  bhurji- egg                                   ...
# 510  flattened rice / pohe                         ...
# 511  puffed rice                                   ...
#
#      catagory      \
# 0    salad
# 1    salad
# 2    chilli
# ...

# %%
df.to_csv("finally.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# h:\FitSync\Ai\test.ipynb Cell 27 line 1
# ----> <a href='vscode-notebook-cell:/h%3A/FitSync/Ai/test.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> df.to_csv("finally.csv")
#
# File c:\Users\Is Laptop\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
# ...

# %%
df = pd.read_csv('finally.csv')
data=pd.read_csv('H:\FitSync\Ai\calories0.csv')

# %%
df['press low']=df['hypertension'].apply(lambda x: False if x else True)

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 1      Meal_Id  \
# 0             0           0  meal_id1
# 1             1           1  meal_id2
# 2             2           2  meal_id3
# 3             3           3  meal_id4
# 4             4           6  meal_id7
# ..          ...         ...          ...
# 310         310         506  meal_id304
# 311         311         508  meal_id306
# 312         312         509  meal_id307
# 313         313         510  meal_id308
# 314         314         511  meal_id309
#
#                                                   Name      catagory  \
# 0    summer squash salad                           ...  salad
# 1    chicken minced salad                          ...  salad
# 2    sweet chilli almonds                          ...  chilli
# 3    tricolour salad                               ...  salad
# 4    chocolate nero cookies                        ...  cookie
# ..                                                 ...           ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Sample categorical data

# Create an instance of LabelEncoder
encoder = LabelEncoder()

# Fit and transform the data
df['press low'] = encoder.fit_transform(df['press low'])

df
# Out:
#      Unnamed: 0  Unnamed: 1      Meal_Id  \
# 0             0           0  meal_id1
# 1             1           1  meal_id2
# 2             2           2  meal_id3
# 3             3           3  meal_id4
# 4             4           6  meal_id7
# ..          ...         ...          ...
# 310         310         506  meal_id304
# 311         311         508  meal_id306
# 312         312         509  meal_id307
# 313         313         510  meal_id308
# 314         314         511  meal_id309
#
#                                                   Name      catagory  \
# 0    summer squash salad                           ...  salad
# 1    chicken minced salad                          ...  salad
# 2    sweet chilli almonds                          ...  chilli
# 3    tricolour salad                               ...  salad
# 4    chocolate nero cookies                        ...  cookie
# ..                                                 ...           ...
# ...

# %%
df['cate'].unique()
# Out:
# array(['white balsamic vinegar, lemon juice, lemon rind, red chillies, garlic cloves (crushed), olive oil, summer squash (zucchini), sea salt, black pepper, basil leaves                                                                                                                                                                                                                                                                                                                                                                                                     ',
# ...

# %%
df['Calories']=np.NaN
df
# Out:
#      Unnamed: 0  Unnamed: 1      Meal_Id  \
# 0             0           0  meal_id1
# 1             1           1  meal_id2
# 2             2           2  meal_id3
# 3             3           3  meal_id4
# 4             4           6  meal_id7
# ..          ...         ...          ...
# 310         310         506  meal_id304
# 311         311         508  meal_id306
# 312         312         509  meal_id307
# 313         313         510  meal_id308
# 314         314         511  meal_id309
#
#                                                   Name      catagory  \
# 0    summer squash salad                           ...  salad
# 1    chicken minced salad                          ...  salad
# 2    sweet chilli almonds                          ...  chilli
# 3    tricolour salad                               ...  salad
# 4    chocolate nero cookies                        ...  cookie
# ..                                                 ...           ...
# ...

# %%
ingrediants={''}
for i in df['description']:
    word=i.split(", ")
    #print(word)
    
    ingrediants.update(word)
for j in ingrediants:
    print(j)
# Out:
# Ghee
# oats
# with curry
# potato (grated)
# salt
# Fresh fish pieces (river sole or sea bass)
# Cinnamon
# turmeric powder
# hazelnut streusel
# n lime and ginger and cooked over an open fire.
# spring onions
# Sage Leaf
# fenugreek (methi)
# clarified butter
# bay leaves
# garlic cloves (minced)
# garlic paste
# peanut oil
# Christmas Mix Spicy
# black olives
# Garam Masala Powder
# almond flakes
# Frozen mixed berries
# wilted spinach
# almond slivers
# written by tamil poet arunagirinathar. pori is offered to hindu gods and goddesses in all poojas in the south indian states of kerala and tamil nadu.
# Peanuts
# sweet chili sauce
# ground chickpea flour (sattu)
# cooking spray
# Wheat flour
# ground black pepper
# clarified butter (desi ghee)
# parsley
# salt or rock salt
# tempura batter
# basmati rice (soaked in water)
# potato
# Vanilla Extract
# French Beans
# potatoes (peeled)
# Cooked Rice
# oil
# eggs (hard boiled and peeled)
# Eggs
# egg white
# fresh coriander
# ...

# %%
data.drop('Unnamed: 0', inplace=True, axis=1)

# %%
data
# Out:
# Empty DataFrame
# ...

# %%
data = pd.DataFrame(columns=[data['Ingredient'], data['Calories per 100 grams']])
# Out:
# C:\Users\Is Laptop\AppData\Local\Temp\ipykernel_49268\4128801260.py:1: DeprecationWarning: Series._data is deprecated and will be removed in a future version. Use public APIs instead.
#   data = pd.DataFrame(columns=[data['Ingredient'], data['Calories per 100 grams']])
# C:\Users\Is Laptop\AppData\Local\Temp\ipykernel_49268\4128801260.py:1: DeprecationWarning: Series._data is deprecated and will be removed in a future version. Use public APIs instead.
#   data = pd.DataFrame(columns=[data['Ingredient'], data['Calories per 100 grams']])

# %%
data
# Out:
# Empty DataFrame
# ...

# %%
data.drop("Ingredient",inplace=True, axis=1)

# %%
data
# Out:
# Empty DataFrame
# ...

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 1      Meal_Id  \
# 0             0           0  meal_id1
# 1             1           1  meal_id2
# 2             2           2  meal_id3
# 3             3           3  meal_id4
# 4             4           6  meal_id7
# ..          ...         ...          ...
# 310         310         506  meal_id304
# 311         311         508  meal_id306
# 312         312         509  meal_id307
# 313         313         510  meal_id308
# 314         314         511  meal_id309
#
#                                                   Name      catagory  \
# 0    summer squash salad                           ...  salad
# 1    chicken minced salad                          ...  salad
# 2    sweet chilli almonds                          ...  chilli
# 3    tricolour salad                               ...  salad
# 4    chocolate nero cookies                        ...  cookie
# ..                                                 ...           ...
# ...

# %%
import csv
import random

def calculate_bmr(age, gender, weight, height):
    if gender.lower() == 'male':
        return 10 * weight + 6.25 * height - 5 * age + 5
    elif gender.lower() == 'female':
        return 10 * weight + 6.25 * height - 5 * age - 161
    else:
        raise ValueError("Invalid gender")

def generate_health_data(num_entries):
    data = []
    for _ in range(num_entries):
        person = chr(random.randint(65, 90))  # Random uppercase letter as a person identifier
        age = random.randint(30, 80)
        gender = random.choice(['Male', 'Female'])
        weight = random.uniform(50, 100)
        height = random.uniform(150, 190)
        activity_level = random.choice(['Sedentary', 'Light', 'Moderate', 'Active', 'Very Active'])
        systolic_bp = random.randint(80, 180)  # Random systolic blood pressure
        diastolic_bp = random.randint(50, 120)  # Random diastolic blood pressure
        cholesterol_level = random.uniform(120, 240)  # Random cholesterol level in mg/dL
        blood_sugar = random.uniform(70, 200)  # Random blood sugar level in mg/dL

        # Introduce different health conditions
        is_hypertension = random.choice([True, False])
        is_low_pressure = random.choice([True, False])
        is_diabetes = random.choice([True, False])
        is_heart_condition = random.choice([True, False])

        # Adjust parameters based on health conditions
        if is_hypertension:
            systolic_bp += 20
            diastolic_bp += 10
        if is_low_pressure:
            systolic_bp -= 20
            diastolic_bp -= 10
        if is_diabetes:
            blood_sugar += 30
        if is_heart_condition:
            cholesterol_level += 30

        bmr = calculate_bmr(age, gender, weight, height)
        total_daily_calories = bmr * random.uniform(1.2, 1.9)  # Adjust for activity level

        # Adjust total daily calories based on health conditions
        total_daily_calories *= (systolic_bp / 140) * (diastolic_bp / 90) * (cholesterol_level / 200) * (blood_sugar / 100)

        data.append([person, age, gender, weight, height, activity_level, systolic_bp, diastolic_bp, cholesterol_level, blood_sugar, is_hypertension, is_low_pressure, is_diabetes, is_heart_condition, bmr, total_daily_calories])

    return data

def save_to_csv(data, filename):
    with open(filename, 'w', newline='') as csvfile:
        fieldnames = ['Person', 'Age', 'Gender', 'Weight', 'Height', 'Activity Level', 'Systolic BP', 'Diastolic BP', 'Cholesterol Level', 'Blood Sugar', 'Hypertension', 'Low Pressure', 'Diabetes', 'Heart Condition', 'BMR', 'Total Daily Calories']
        writer = csv.writer(csvfile)
        writer.writerow(fieldnames)
        writer.writerows(data)

# Generate 1000 entries and save to a CSV file named 'health_data_combined.csv'
health_data_combined = generate_health_data(1000)
save_to_csv(health_data_combined, 'health_data_combined.csv')

# %%
d=pd.read_csv('health_data_combined.csv')
d
# Out:
#     Person  Age  Gender     Weight      Height Activity Level  Systolic BP  \
# 0        F   52    Male  97.830784  157.397234         Active           86
# 1        Q   73  Female  94.510453  164.394989      Sedentary          146
# 2        S   30    Male  56.829855  175.816341         Active           81
# 3        C   30  Female  55.989318  174.897727         Active          129
# 4        G   61  Female  87.058392  172.276494          Light          123
# ..     ...  ...     ...        ...         ...            ...          ...
# 995      A   48  Female  89.756327  182.313879    Very Active          125
# 996      D   64  Female  50.341089  169.000889    Very Active           81
# 997      T   38  Female  73.968763  179.334950      Sedentary           84
# 998      V   34    Male  50.840601  187.807349         Active           98
# 999      X   65  Female  65.950203  160.762764         Active          153
#
# ...

# %%
import csv
import random

def generate_exercise_data(num_entries):
    data = []
    for _ in range(num_entries):
        exercise_type = random.choice(['Aerobic', 'Strength Training', 'Flexibility', 'Balance'])
        duration_minutes = random.randint(10, 60)
        intensity_level = random.choice(['Low', 'Moderate', 'High'])

        # Introduce different health conditions
        is_hypertension = random.choice([True, False])
        is_low_pressure = random.choice([True, False])
        is_diabetes = random.choice([True, False])
        is_heart_condition = random.choice([True, False])

        # Adjust exercise recommendations based on health conditions
        if is_hypertension:
            if exercise_type == 'Aerobic':
                intensity_level = 'Low'  # Modify intensity for hypertension
            elif exercise_type == 'Strength Training':
                intensity_level = 'Moderate'  # Modify intensity for hypertension
        if is_low_pressure:
            if exercise_type == 'Aerobic':
                intensity_level = 'Moderate'  # Modify intensity for low pressure
            elif exercise_type == 'Strength Training':
                intensity_level = 'Low'  # Modify intensity for low pressure
        if is_diabetes:
            if exercise_type == 'Aerobic':
                duration_minutes += 10  # Increase duration for diabetes
            elif exercise_type == 'Flexibility':
                duration_minutes -= 10  # Decrease duration for flexibility exercises for diabetes
        if is_heart_condition:
            if exercise_type == 'Aerobic':
                intensity_level = 'Low'  # Modify intensity for heart conditions
            elif exercise_type == 'Strength Training':
                intensity_level = 'Moderate'  # Modify intensity for heart conditions
            elif exercise_type == 'Flexibility':
                duration_minutes += 10  # Increase duration for flexibility exercises for heart conditions

        data.append([exercise_type, duration_minutes, intensity_level, is_hypertension, is_low_pressure, is_diabetes, is_heart_condition])

    return data

def save_to_csv(data, filename):
    with open(filename, 'w', newline='') as csvfile:
        fieldnames = ['Exercise Type', 'Duration (minutes)', 'Intensity Level', 'Hypertension', 'Low Pressure', 'Diabetes', 'Heart Condition']
        writer = csv.writer(csvfile)
        writer.writerow(fieldnames)
        writer.writerows(data)

# Generate 1000 entries and save to a CSV file named 'exercise_data_combined.csv'
exercise_data_combined = generate_exercise_data(1000)
save_to_csv(exercise_data_combined, 'exercise_data_combined.csv')

# %%
l=pd.read_csv('exercise_data_combined.csv')
l
# Out:
#          Exercise Type  Duration (minutes) Intensity Level  Hypertension  \
# 0          Flexibility                  50            High          True
# 1          Flexibility                  33            High          True
# 2          Flexibility                  30        Moderate         False
# 3          Flexibility                  39        Moderate         False
# 4              Balance                  55            High         False
# ..                 ...                 ...             ...           ...
# 995            Balance                  39            High         False
# 996  Strength Training                  27        Moderate          True
# 997            Aerobic                  22        Moderate         False
# 998  Strength Training                  59        Moderate         False
# 999        Flexibility                  52             Low          True
#
#      Low Pressure  Diabetes  Heart Condition
# 0           False     False            False
# ...

# %%
df['cal']=np.NAN
sum = 0
for i in df['description']:
    word=i.split(', ')
    for j in df['cal']:
        
            v=float(data[word])
            sum+=v
            j.fillna(value=sum)
                   
        

df['cal']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# h:\FitSync\Ai\test.ipynb Cell 48 line 7
#       <a href='vscode-notebook-cell:/h%3A/FitSync/Ai/test.ipynb#X65sZmlsZQ%3D%3D?line=3'>4</a> word=i.split(', ')
#       <a href='vscode-notebook-cell:/h%3A/FitSync/Ai/test.ipynb#X65sZmlsZQ%3D%3D?line=4'>5</a> for j in df['cal']:
# ----> <a href='vscode-notebook-cell:/h%3A/FitSync/Ai/test.ipynb#X65sZmlsZQ%3D%3D?line=6'>7</a>         v=float(data[word])
#       <a href='vscode-notebook-cell:/h%3A/FitSync/Ai/test.ipynb#X65sZmlsZQ%3D%3D?line=7'>8</a>         sum+=v
#       <a href='vscode-notebook-cell:/h%3A/FitSync/Ai/test.ipynb#X65sZmlsZQ%3D%3D?line=8'>9</a>         j.fillna(value=sum)
#
# File c:\Users\Is Laptop\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
# ...

# %%
data['1 Fried Onion (Medium)']
# Out:
# Empty DataFrame
# Columns: [280]
# Index: []
