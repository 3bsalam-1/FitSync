# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("testmeal.csv")
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 1      Meal_Id  \
# 0           0           0  meal_id1
# 1           1           1  meal_id2
#
#                                                 Name      catagory  \
# 0  summer squash salad                           ...  salad
# 1  chicken minced salad                          ...  salad
#
#                                          description   Veg_Non  \
# 0  white balsamic vinegar, lemon juice, lemon rin...  veg
# 1  olive oil, chicken mince, garlic (minced), oni...  non-veg
#
#          Nutrient                                               Diet  \
# 0  fiber           alkaline_diet low_fat_diet ketogenic_diet low_...
# 1  fiber           low_fat_diet low_carb_diet ketogenic_diet low_...
#
#    diabeties  heart_disease  hypertension
# 0          1              0             1
# 1          0              0             1

# %%
df.drop(["Unnamed: 0","Unnamed: 1"],inplace=True ,axis=1)
df.head(2)
# Out:
#        Meal_Id                                               Name  \
# 0  meal_id1     summer squash salad                           ...
# 1  meal_id2     chicken minced salad                          ...
#
#        catagory                                        description   Veg_Non  \
# 0  salad         white balsamic vinegar, lemon juice, lemon rin...  veg
# 1  salad         olive oil, chicken mince, garlic (minced), oni...  non-veg
#
#          Nutrient                                               Diet  \
# 0  fiber           alkaline_diet low_fat_diet ketogenic_diet low_...
# 1  fiber           low_fat_diet low_carb_diet ketogenic_diet low_...
#
#    diabeties  heart_disease  hypertension
# 0          1              0             1
# 1          0              0             1

# %%
df.insert(0, 'id', df.index)
df.head(5)
# Out:
#    id      Meal_Id                                               Name  \
# 0   0  meal_id1     summer squash salad                           ...
# 1   1  meal_id2     chicken minced salad                          ...
# 2   2  meal_id3     sweet chilli almonds                          ...
# 3   3  meal_id4     tricolour salad                               ...
# 4   4  meal_id7     chocolate nero cookies                        ...
#
#        catagory                                        description   Veg_Non  \
# 0  salad         white balsamic vinegar, lemon juice, lemon rin...  veg
# 1  salad         olive oil, chicken mince, garlic (minced), oni...  non-veg
# 2  chilli        almonds whole, egg white, curry leaves, salt, ...  veg
# 3  salad         vinegar, honey/sugar, soy sauce, salt, garlic ...  veg
# 4  cookie        almonds, eggs, granulated sugar, bittersweet c...  veg
#
#          Nutrient                                               Diet  \
# 0  fiber           alkaline_diet low_fat_diet ketogenic_diet low_...
# 1  fiber           low_fat_diet low_carb_diet ketogenic_diet low_...
# 2  vitamin_a       alkaline_diet low_fat_diet paleo_diet Mediterr...
# 3  fiber           low_fat_diet ketogenic_diet low_sodium_diet hi...
# 4  magnesium       high_protien_diet high_fiber_diet ketogenic_di...
#
#    diabeties  heart_disease  hypertension
# 0          1              0             1
# 1          0              0             1
# 2          0              1             1
# 3          0              0             1
# 4          0              1             1

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315 entries, 0 to 314
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             315 non-null    int64
#  1   Meal_Id        315 non-null    object
#  2   Name           315 non-null    object
#  3   catagory       315 non-null    object
#  4   description    315 non-null    object
#  5   Veg_Non        315 non-null    object
#  6   Nutrient       315 non-null    object
#  7   Diet           315 non-null    object
#  8   diabeties      315 non-null    int64
#  9   heart_disease  315 non-null    int64
#  10  hypertension   315 non-null    int64
# dtypes: int64(4), object(7)
# memory usage: 27.2+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# Sample categorical data

# Create an instance of LabelEncoder
encoder = LabelEncoder()

# Fit and transform the data
df['Veg_Non'] = encoder.fit_transform(df['Veg_Non'])
df.head(5)
# Out:
#    id      Meal_Id                                               Name  \
# 0   0  meal_id1     summer squash salad                           ...
# 1   1  meal_id2     chicken minced salad                          ...
# 2   2  meal_id3     sweet chilli almonds                          ...
# 3   3  meal_id4     tricolour salad                               ...
# 4   4  meal_id7     chocolate nero cookies                        ...
#
#        catagory                                        description  Veg_Non  \
# 0  salad         white balsamic vinegar, lemon juice, lemon rin...        1
# 1  salad         olive oil, chicken mince, garlic (minced), oni...        0
# 2  chilli        almonds whole, egg white, curry leaves, salt, ...        1
# 3  salad         vinegar, honey/sugar, soy sauce, salt, garlic ...        1
# 4  cookie        almonds, eggs, granulated sugar, bittersweet c...        1
#
#          Nutrient                                               Diet  \
# 0  fiber           alkaline_diet low_fat_diet ketogenic_diet low_...
# 1  fiber           low_fat_diet low_carb_diet ketogenic_diet low_...
# 2  vitamin_a       alkaline_diet low_fat_diet paleo_diet Mediterr...
# 3  fiber           low_fat_diet ketogenic_diet low_sodium_diet hi...
# 4  magnesium       high_protien_diet high_fiber_diet ketogenic_di...
#
#    diabeties  heart_disease  hypertension
# 0          1              0             1
# 1          0              0             1
# 2          0              1             1
# 3          0              0             1
# 4          0              1             1

# %%
# Calculate min and max
min_value = np.min(df['id'])
max_value = np.max(df['id'])

# Standardize the data
normalized_data = (df['id'] - min_value) / (max_value - min_value)
df['id']=normalized_data

# %%
df.head(5)
# Out:
#          id      Meal_Id                                               Name  \
# 0  0.000000  meal_id1     summer squash salad                           ...
# 1  0.003185  meal_id2     chicken minced salad                          ...
# 2  0.006369  meal_id3     sweet chilli almonds                          ...
# 3  0.009554  meal_id4     tricolour salad                               ...
# 4  0.012739  meal_id7     chocolate nero cookies                        ...
#
#        catagory                                        description  Veg_Non  \
# 0  salad         white balsamic vinegar, lemon juice, lemon rin...        1
# 1  salad         olive oil, chicken mince, garlic (minced), oni...        0
# 2  chilli        almonds whole, egg white, curry leaves, salt, ...        1
# 3  salad         vinegar, honey/sugar, soy sauce, salt, garlic ...        1
# 4  cookie        almonds, eggs, granulated sugar, bittersweet c...        1
#
#          Nutrient                                               Diet  \
# 0  fiber           alkaline_diet low_fat_diet ketogenic_diet low_...
# 1  fiber           low_fat_diet low_carb_diet ketogenic_diet low_...
# 2  vitamin_a       alkaline_diet low_fat_diet paleo_diet Mediterr...
# 3  fiber           low_fat_diet ketogenic_diet low_sodium_diet hi...
# 4  magnesium       high_protien_diet high_fiber_diet ketogenic_di...
#
#    diabeties  heart_disease  hypertension
# 0          1              0             1
# 1          0              0             1
# 2          0              1             1
# 3          0              0             1
# 4          0              1             1

# %%
df1 = df[["id","diabeties","heart_disease","hypertension"]]
df1.head(2)
# Out:
#          id  diabeties  heart_disease  hypertension
# 0  0.000000          1              0             1
# 1  0.003185          0              0             1

# %%
df2 = df[["id","Name","catagory","description","Veg_Non","Meal_Id","Nutrient","Diet"]]
df2.head(2)
# Out:
#          id                                               Name      catagory  \
# 0  0.000000  summer squash salad                           ...  salad
# 1  0.003185  chicken minced salad                          ...  salad
#
#                                          description  Veg_Non      Meal_Id  \
# 0  white balsamic vinegar, lemon juice, lemon rin...        1  meal_id1
# 1  olive oil, chicken mince, garlic (minced), oni...        0  meal_id2
#
#          Nutrient                                               Diet
# 0  fiber           alkaline_diet low_fat_diet ketogenic_diet low_...
# 1  fiber           low_fat_diet low_carb_diet ketogenic_diet low_...

# %%
df1.hist(bins=100, figsize=(20,15))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot scatter matrix to visualize relationships between numerical variables
sns.pairplot(df1)
plt.show()
# Compute the correlation matrix
correlation_matrix = df1.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Matrix')
plt.show()

# %%
# Function to detect outliers
def detect_outliers(dataframe, column):
    Q1 = dataframe[column].quantile(0.25)
    Q3 = dataframe[column].quantile(0.75)
    IQR = Q3 - Q1
    outliers = dataframe[(dataframe[column] < Q1 - 1.5*IQR) | (dataframe[column] > Q3 + 1.5*IQR)]
    return outliers

# Detect and print number of outliers for each feature
for column in df1.columns:
    outliers = detect_outliers(df1, column)
    print(f'Number of outliers in {column}: {len(outliers)}')
# Out:
# Number of outliers in id: 0
# Number of outliers in diabeties: 0
# Number of outliers in heart_disease: 0
# Number of outliers in hypertension: 0

# %%
print("Descriptive Statistics:")
print(df1.describe())

# Check for duplicates
print("Number of duplicate rows: ", df1.duplicated().sum())

# Distribution plots for each feature
for column in df1.columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(df1[column], bins=30, kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()
# Out:
# Descriptive Statistics:
#                id   diabeties  heart_disease  hypertension
# count  315.000000  315.000000     315.000000    315.000000
# mean     0.500000    0.511111       0.501587      0.698413
# std      0.290054    0.500672       0.500793      0.459677
# min      0.000000    0.000000       0.000000      0.000000
# 25%      0.250000    0.000000       0.000000      0.000000
# 50%      0.500000    1.000000       1.000000      1.000000
# 75%      0.750000    1.000000       1.000000      1.000000
# max      1.000000    1.000000       1.000000      1.000000
# Number of duplicate rows:  0

# %%
sns.boxplot(data=df1, orient="h")
plt.xlabel("Value")
plt.ylabel("Frequency")
#plt.title("ID")
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df1), columns=df1.columns)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Calculate WCSS for different number of clusters
wcss = []
max_clusters = 15
for i in range(1, max_clusters+1):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(df1)
    wcss.append(kmeans.inertia_)

# Plot the WCSS values
plt.plot(range(1, max_clusters+1), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import KMeans

# Build the model
kmeans = KMeans(n_clusters=7, init='k-means++', random_state=42)
kmeans.fit(df1)

# Get cluster labels
cluster_labels = kmeans.labels_

# Add cluster labels to your original dataframe
df1['Cluster'] = cluster_labels

df1.head()
# Out:
#          id  diabeties  heart_disease  hypertension  Cluster
# 0  0.000000          1              0             1        6
# 1  0.003185          0              0             1        3
# 2  0.006369          0              1             1        1
# 3  0.009554          0              0             1        3
# 4  0.012739          0              1             1        1

# %%
df1['Cluster'] = kmeans.labels_

# Check the size of each cluster
print("Cluster Sizes:\n", df1['Cluster'].value_counts())
# Out:
# Cluster Sizes:
#  Cluster
# 3    78
# 0    65
# 2    59
# 1    57
# 6    20
# 5    19
# 4    17
# Name: count, dtype: int64

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Apply PCA and fit the features selected
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(df1.drop('Cluster', axis=1))

# Create a DataFrame with the two components
PCA_components = pd.DataFrame(principalComponents, columns=['Principal Component 1', 'Principal Component 2'])

# Concatenate the clusters labels to the DataFrame
PCA_components['Cluster'] = df1['Cluster']

# Plot the clustered dataset
plt.figure(figsize=(8,6))
plt.scatter(PCA_components['Principal Component 1'], PCA_components['Principal Component 2'], c=PCA_components['Cluster'])
plt.title('Clusters in PCA 2D Space')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster')
plt.show()

# %%
df1
# Out:
#            id  diabeties  heart_disease  hypertension  Cluster
# 0    0.000000          1              0             1        6
# 1    0.003185          0              0             1        3
# 2    0.006369          0              1             1        1
# 3    0.009554          0              0             1        3
# 4    0.012739          0              1             1        1
# ..        ...        ...            ...           ...      ...
# 310  0.987261          1              0             0        2
# 311  0.990446          0              0             1        3
# 312  0.993631          1              0             1        6
# 313  0.996815          1              1             0        4
# 314  1.000000          1              0             0        2
#
# [315 rows x 5 columns]
