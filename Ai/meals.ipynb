# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df= pd.read_csv("testmeal.csv")

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 1      Meal_Id  \
# 0             0           0  meal_id1
# 1             1           1  meal_id2
# 2             2           2  meal_id3
# 3             3           3  meal_id4
# 4             4           6  meal_id7
# ..          ...         ...          ...
# 310         310         506  meal_id304
# 311         311         508  meal_id306
# 312         312         509  meal_id307
# 313         313         510  meal_id308
# 314         314         511  meal_id309
#
#                                                   Name      catagory  \
# 0    summer squash salad                           ...  salad
# 1    chicken minced salad                          ...  salad
# 2    sweet chilli almonds                          ...  chilli
# 3    tricolour salad                               ...  salad
# 4    chocolate nero cookies                        ...  cookie
# ..                                                 ...           ...
# ...

# %%
df.drop(columns=['Unnamed: 0', 'Unnamed: 1', 'Meal_Id'], inplace=True,axis=1)

# %%
df
# Out:
#                                                   Name      catagory  \
# 0    summer squash salad                           ...  salad
# 1    chicken minced salad                          ...  salad
# 2    sweet chilli almonds                          ...  chilli
# 3    tricolour salad                               ...  salad
# 4    chocolate nero cookies                        ...  cookie
# ..                                                 ...           ...
# 310  rice                                          ...  rice
# 311  banana chips                                  ...  banana
# 312  bhurji- egg                                   ...  egg
# 313  flattened rice / pohe                         ...  rice
# 314  puffed rice                                   ...  rice
#
#                                            description   Veg_Non  \
# 0    white balsamic vinegar, lemon juice, lemon rin...  veg
# 1    olive oil, chicken mince, garlic (minced), oni...  non-veg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315 entries, 0 to 314
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           315 non-null    object
#  1   catagory       315 non-null    object
#  2   description    315 non-null    object
#  3   Veg_Non        315 non-null    object
#  4   Nutrient       315 non-null    object
#  5   Diet           315 non-null    object
#  6   diabeties      315 non-null    int64
#  7   heart_disease  315 non-null    int64
#  8   hypertension   315 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 22.3+ KB

# %%
df.describe()
# Out:
#         diabeties  heart_disease  hypertension
# count  315.000000     315.000000    315.000000
# mean     0.511111       0.501587      0.698413
# std      0.500672       0.500793      0.459677
# min      0.000000       0.000000      0.000000
# 25%      0.000000       0.000000      0.000000
# 50%      1.000000       1.000000      1.000000
# 75%      1.000000       1.000000      1.000000
# max      1.000000       1.000000      1.000000

# %%
df['low pressure']=np.where(df["hypertension"]==0,1,0)

# %%
df
# Out:
#                                                   Name      catagory  \
# 0    summer squash salad                           ...  salad
# 1    chicken minced salad                          ...  salad
# 2    sweet chilli almonds                          ...  chilli
# 3    tricolour salad                               ...  salad
# 4    chocolate nero cookies                        ...  cookie
# ..                                                 ...           ...
# 310  rice                                          ...  rice
# 311  banana chips                                  ...  banana
# 312  bhurji- egg                                   ...  egg
# 313  flattened rice / pohe                         ...  rice
# 314  puffed rice                                   ...  rice
#
#                                            description   Veg_Non  \
# 0    white balsamic vinegar, lemon juice, lemon rin...  veg
# 1    olive oil, chicken mince, garlic (minced), oni...  non-veg
# ...

# %%
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 224 entries, 0 to 314
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           224 non-null    object
#  1   catagory       224 non-null    object
#  2   description    224 non-null    object
#  3   Veg_Non        224 non-null    object
#  4   Nutrient       224 non-null    object
#  5   Diet           224 non-null    object
#  6   diabeties      224 non-null    int64
#  7   heart_disease  224 non-null    int64
#  8   hypertension   224 non-null    int64
#  9   low pressure   224 non-null    int32
# dtypes: int32(1), int64(3), object(6)
# memory usage: 18.4+ KB

# %%
df['Veg_Non'].unique()
# Out:
# array(['veg     ', 'non-veg '], dtype=object)

# %%
df=df.drop('Nutrient',axis=1)

# %%
df=df.drop('Diet',axis=1)

# %%
df.head()
# Out:
#                                                 Name      catagory  \
# 0  summer squash salad                           ...  salad
# 1  chicken minced salad                          ...  salad
# 2  sweet chilli almonds                          ...  chilli
# 3  tricolour salad                               ...  salad
# 4  chocolate nero cookies                        ...  cookie
#
#                                          description   Veg_Non  diabeties  \
# 0  white balsamic vinegar, lemon juice, lemon rin...  veg               1
# 1  olive oil, chicken mince, garlic (minced), oni...  non-veg           0
# 2  almonds whole, egg white, curry leaves, salt, ...  veg               0
# 3  vinegar, honey/sugar, soy sauce, salt, garlic ...  veg               0
# 4  almonds, eggs, granulated sugar, bittersweet c...  veg               0
#
#    heart_disease  hypertension  low pressure
# 0              0             1             0
# 1              0             1             0
# ...

# %%
df.head()
# Out:
#                                                 Name      catagory  \
# 0  summer squash salad                           ...  salad
# 1  chicken minced salad                          ...  salad
# 2  sweet chilli almonds                          ...  chilli
# 3  tricolour salad                               ...  salad
# 4  chocolate nero cookies                        ...  cookie
#
#                                          description   Veg_Non  diabeties  \
# 0  white balsamic vinegar, lemon juice, lemon rin...  veg               1
# 1  olive oil, chicken mince, garlic (minced), oni...  non-veg           0
# 2  almonds whole, egg white, curry leaves, salt, ...  veg               0
# 3  vinegar, honey/sugar, soy sauce, salt, garlic ...  veg               0
# 4  almonds, eggs, granulated sugar, bittersweet c...  veg               0
#
#    heart_disease  hypertension  low pressure
# 0              0             1             0
# 1              0             1             0
# ...

# %%
 
from sklearn import preprocessing 
  
# label_encoder object knows  
# how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
df['Veg_Non']= label_encoder.fit_transform(df['Veg_Non']) 
df
# Out:
#                                                   Name      catagory  \
# 0    summer squash salad                           ...  salad
# 1    chicken minced salad                          ...  salad
# 2    sweet chilli almonds                          ...  chilli
# 3    tricolour salad                               ...  salad
# 4    chocolate nero cookies                        ...  cookie
# ..                                                 ...           ...
# 310  rice                                          ...  rice
# 311  banana chips                                  ...  banana
# 312  bhurji- egg                                   ...  egg
# 313  flattened rice / pohe                         ...  rice
# 314  puffed rice                                   ...  rice
#
#                                            description  Veg_Non  diabeties  \
# 0    white balsamic vinegar, lemon juice, lemon rin...        1          1
# ...
