# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('H:\FitSync\Ai\data\heartbeat\heartbeats_data1.csv')

# %%
df.head(15)
# Out:
#     Gender  Age  Height (cm)  Weight (kg)  Hypertension  Low Pressure  \
# 0     Male   55   182.231019    63.859416          True         False
# 1     Male   25   181.646056    84.958526         False          True
# 2     Male   68   183.417645    72.605945         False          True
# 3     Male   58   188.673014    72.040961         False         False
# 4     Male   24   182.745600    55.134321         False          True
# 5     Male   75   186.665192    77.815978          True         False
# 6     Male   77   172.631635    67.929501         False          True
# 7     Male   80   170.826800    70.520104         False         False
# 8     Male   25   154.079641    77.078320          True          True
# 9     Male   57   176.147831    74.841290          True          True
# 10  Female   19   187.680788    59.483370         False          True
# 11  Female   26   156.246249    56.278650         False         False
# ...

# %%
df['Heartbeat Range'].unique()
# Out:
# array(['80-120', '60-63', '60-64', '78-80', '60-65', '100-120', '60-71',
#        '79-80', '77-120', '105-120', '60-88', '102-83', '60-69', '60-75',
#        '106-120', '60-70', '68-100', '69-100', '62-80', '98-120',
#        '82-120', '73-120', '84-120', '60-77', '87-63', '60-95', '65-120',
#        '64-120', '61-80', '75-120', '90-80', '60-58', '74-120', '78-120',
#        '80-100', '60-59', '83-120', '83-64', '81-120', '60-82', '66-80',
#        '76-120', '104-120', '102-120', '97-120', '90-120', '79-100',
#        '71-120', '68-120', '93-100', '73-58', '84-100', '88-120', '60-61',
#        '89-120', '97-100', '70-100', '94-71', '101-120', '60-100',
#        '60-92', '71-100', '72-80', '62-100', '99-120', '96-71', '60-66',
#        '93-120', '63-120', '60-90', '83-100', '60-86', '65-100',
#        '110-120', '79-120', '60-57', '60-76', '87-120', '86-100', '69-80',
#        '101-80', '90-100', '67-120', '99-100', '94-120', '72-120',
# ...

# %%
df.drop_duplicates()
# Out:
#      Gender  Age  Height (cm)  Weight (kg)  Hypertension  Low Pressure  \
# 0      Male   55   182.231019    63.859416          True         False
# 1      Male   25   181.646056    84.958526         False          True
# 2      Male   68   183.417645    72.605945         False          True
# 3      Male   58   188.673014    72.040961         False         False
# 4      Male   24   182.745600    55.134321         False          True
# ..      ...  ...          ...          ...           ...           ...
# 995    Male   49   180.712077    80.002019         False         False
# 996  Female   41   162.692129    84.153349          True          True
# 997    Male   49   189.100314    88.811213          True          True
# 998    Male   70   183.325630    66.897865         False         False
# 999    Male   50   156.630905    94.517843          True         False
#
#      Diabetes  Heart Condition Heartbeat Range
# 0       False            False          80-120
# ...

# %%
df = pd.read_csv('H:\FitSync\Ai\data\heartbeat\heartbeats_data1.csv')
df[['min','max']] = df['Heartbeat Range'].str.split('-', expand=True)
df.drop(['Heartbeat Range'], axis=1, inplace=True)

df.to_csv('heartbeats3.csv', index=False)

# %%
df=pd.read_csv('H:\FitSync\Ai\heartbeats3.csv')

# %%
df.head(15)
# Out:
#     Gender  Age  Height (cm)  Weight (kg)  Hypertension  Low Pressure  \
# 0     Male   55   182.231019    63.859416          True         False
# 1     Male   25   181.646056    84.958526         False          True
# 2     Male   68   183.417645    72.605945         False          True
# 3     Male   58   188.673014    72.040961         False         False
# 4     Male   24   182.745600    55.134321         False          True
# 5     Male   75   186.665192    77.815978          True         False
# 6     Male   77   172.631635    67.929501         False          True
# 7     Male   80   170.826800    70.520104         False         False
# 8     Male   25   154.079641    77.078320          True          True
# 9     Male   57   176.147831    74.841290          True          True
# 10  Female   19   187.680788    59.483370         False          True
# 11  Female   26   156.246249    56.278650         False         False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           1000 non-null   object
#  1   Age              1000 non-null   int64
#  2   Height (cm)      1000 non-null   float64
#  3   Weight (kg)      1000 non-null   float64
#  4   Hypertension     1000 non-null   bool
#  5   Low Pressure     1000 non-null   bool
#  6   Diabetes         1000 non-null   bool
#  7   Heart Condition  1000 non-null   bool
#  8   min              1000 non-null   int64
#  9   max              1000 non-null   int64
# dtypes: bool(4), float64(2), int64(3), object(1)
# memory usage: 50.9+ KB

# %%
df.columns = df.columns.str.strip()
df.columns = df.columns.str.capitalize()

# %%
df.head(5)
# Out:
#   Gender  Age  Height (cm)  Weight (kg)  Hypertension  Low pressure  Diabetes  \
# 0   Male   55   182.231019    63.859416          True         False     False
# 1   Male   25   181.646056    84.958526         False          True     False
# 2   Male   68   183.417645    72.605945         False          True      True
# 3   Male   58   188.673014    72.040961         False         False     False
# 4   Male   24   182.745600    55.134321         False          True      True
#
#    Heart condition  Min  Max
# 0            False   80  120
# 1            False   60   63
# 2            False   60   64
# 3            False   78   80
# 4            False   60   65

# %%
from sklearn.preprocessing import LabelEncoder

# Sample categorical data

# Create an instance of LabelEncoder
encoder = LabelEncoder()

# Fit and transform the data
df['Gender'] = encoder.fit_transform(df['Gender'])
df['Hypertension'] = encoder.fit_transform(df['Hypertension'])
df['Low pressure'] = encoder.fit_transform(df['Low pressure'])
df['Diabetes'] = encoder.fit_transform(df['Diabetes'])
df['Heart condition'] = encoder.fit_transform(df['Heart condition'])
df.head(5)
# Out:
#    Gender  Age  Height (cm)  Weight (kg)  Hypertension  Low pressure  \
# 0       1   55   182.231019    63.859416             1             0
# 1       1   25   181.646056    84.958526             0             1
# 2       1   68   183.417645    72.605945             0             1
# 3       1   58   188.673014    72.040961             0             0
# 4       1   24   182.745600    55.134321             0             1
#
#    Diabetes  Heart condition  Min  Max
# 0         0                0   80  120
# 1         0                0   60   63
# 2         1                0   60   64
# 3         0                0   78   80
# 4         1                0   60   65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           1000 non-null   int32
#  1   Age              1000 non-null   int64
#  2   Height (cm)      1000 non-null   float64
#  3   Weight (kg)      1000 non-null   float64
#  4   Hypertension     1000 non-null   int64
#  5   Low pressure     1000 non-null   int64
#  6   Diabetes         1000 non-null   int64
#  7   Heart condition  1000 non-null   int64
#  8   Min              1000 non-null   int64
#  9   Max              1000 non-null   int64
# dtypes: float64(2), int32(1), int64(7)
# memory usage: 74.3 KB

# %%
#y1_predict = y1_predict.astype(int)
df['Min']=df['Min'].astype(int)
df['Max']=df['Max'].astype(int)
df['Height (cm)']=df['Height (cm)'].round()
df['Weight (kg)']=df['Weight (kg)'].round()
df['Height (cm)']=df['Height (cm)'].astype(int)
df['Weight (kg)']=df['Weight (kg)'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           1000 non-null   int32
#  1   Age              1000 non-null   int64
#  2   Height (cm)      1000 non-null   int32
#  3   Weight (kg)      1000 non-null   int32
#  4   Hypertension     1000 non-null   int64
#  5   Low pressure     1000 non-null   int64
#  6   Diabetes         1000 non-null   int64
#  7   Heart condition  1000 non-null   int64
#  8   Min              1000 non-null   int32
#  9   Max              1000 non-null   int32
# dtypes: int32(5), int64(5)
# memory usage: 58.7 KB

# %%
for i in range(len(df)):
    #print(i)

    df = df.drop(df[(df['Hypertension'] == 1) & (df['Low pressure'] ==1)].index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 756 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           756 non-null    int32
#  1   Age              756 non-null    int64
#  2   Height (cm)      756 non-null    int32
#  3   Weight (kg)      756 non-null    int32
#  4   Hypertension     756 non-null    int64
#  5   Low pressure     756 non-null    int64
#  6   Diabetes         756 non-null    int64
#  7   Heart condition  756 non-null    int64
#  8   Min              756 non-null    int32
#  9   Max              756 non-null    int32
# dtypes: int32(5), int64(5)
# memory usage: 50.2 KB

# %%
for i in range(len(df)):
    #print(i)
       if df.iloc[i,8] > df.iloc[i,9]:
              temp=df.iloc[i,8]
              df.iloc[i,8]=df.iloc[i,9]
              df.iloc[i,9]=temp

# %%
#df = df.sort_values(by=["Min","Max"], ascending=False)

# %%
df.head(15)
# Out:
#     Gender  Age  Height (cm)  Weight (kg)  Hypertension  Low pressure  \
# 0        1   55          182           64             1             0
# 1        1   25          182           85             0             1
# 2        1   68          183           73             0             1
# 3        1   58          189           72             0             0
# 4        1   24          183           55             0             1
# 5        1   75          187           78             1             0
# 6        1   77          173           68             0             1
# 7        1   80          171           71             0             0
# 10       0   19          188           59             0             1
# 11       0   26          156           56             0             0
# 12       0   75          165           94             0             1
# 13       0   78          160           67             0             1
# ...

# %%
# Function to detect outliers
def detect_outliers(dataframe, column):
    Q1 = dataframe[column].quantile(0.25)
    Q3 = dataframe[column].quantile(0.75)
    IQR = Q3 - Q1
    outliers = dataframe[(dataframe[column] < Q1 - 1.5*IQR) | (dataframe[column] > Q3 + 1.5*IQR)]
    return outliers

# Detect and print number of outliers for each feature
for column in df.columns:
    outliers = detect_outliers(df, column)
    print(f'Number of outliers in {column}: {len(outliers)}')
# Out:
# Number of outliers in Gender: 0
# Number of outliers in Age: 0
# Number of outliers in Height (cm): 0
# Number of outliers in Weight (kg): 0
# Number of outliers in Hypertension: 0
# Number of outliers in Low pressure: 0
# Number of outliers in Diabetes: 0
# Number of outliers in Heart condition: 0
# Number of outliers in Min: 0
# Number of outliers in Max: 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot scatter matrix to visualize relationships between numerical variables
sns.pairplot(df)
plt.show()
# Compute the correlation matrix
#correlation_matrix = df.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Matrix')
plt.show()

# %%
print(df['Min'].corr(df['Max']))
print(df['Min'].corr(df['Low pressure']))
print(df['Min'].corr(df['Hypertension']))
print(df['Min'].corr(df['Height (cm)']))
print(df['Min'].corr(df['Weight (kg)']))
print(df['Min'].corr(df['Gender']))
print(df['Min'].corr(df['Age']))
# Out:
# 0.714862164411961
# -0.6944865556782533
# 0.5657815722206886
# -0.010317568877116174
# 0.03498324983713245
# -0.04706121790606161
# -0.014276062435895858

# %%
print(120 *0.714862164411961+.5657815722206886-0.04706121790606161+(-0.014276062435895858*55)+(-0.010317568877116174*182)+(64*0.03498324983713245))
# Out:
# 85.87812710371702

# %%
sns.boxplot(data=df, orient="h")
plt.xlabel("Value")
plt.ylabel("Frequency")
#plt.title("ID")
plt.tight_layout()
plt.show()

# %%
for column in df.columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[column], bins=30)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
df[df['Min']==0]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Height (cm), Weight (kg), Hypertension, Low pressure, Diabetes, Heart condition, Min, Max]
# Index: []

# %%
df[df['Max']==0]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Height (cm), Weight (kg), Hypertension, Low pressure, Diabetes, Heart condition, Min, Max]
# Index: []

# %%
df.to_csv('heartbeats_00.csv', index=False)

# %%
df.head(15)
# Out:
#     Gender  Age  Height (cm)  Weight (kg)  Hypertension  Low pressure  \
# 0        1   55          182           64             1             0
# 1        1   25          182           85             0             1
# 2        1   68          183           73             0             1
# 3        1   58          189           72             0             0
# 4        1   24          183           55             0             1
# 5        1   75          187           78             1             0
# 6        1   77          173           68             0             1
# 7        1   80          171           71             0             0
# 10       0   19          188           59             0             1
# 11       0   26          156           56             0             0
# 12       0   75          165           94             0             1
# 13       0   78          160           67             0             1
# ...

# %%
# Import libraries for machine learning
from sklearn.linear_model import LinearRegression

# %%
train=pd.read_csv('heartbeats_00.csv')

# %%
train.columns = df.columns.str.strip()
train.columns = df.columns.str.capitalize()

# %%
from sklearn.preprocessing import LabelEncoder

# Sample categorical data

# Create an instance of LabelEncoder
encoder = LabelEncoder()

# Fit and transform the data
train['Gender'] = encoder.fit_transform(train['Gender'])

train['Hypertension'] = encoder.fit_transform(train['Hypertension'])
train['Low pressure'] = encoder.fit_transform(train['Low pressure'])
train['Diabetes'] = encoder.fit_transform(train['Diabetes'])
train['Heart condition'] = encoder.fit_transform(train['Heart condition'])



train.head(15)
# Out:
#     Gender  Age  Height (cm)  Weight (kg)  Hypertension  Low pressure  \
# 0        1   55          182           64             1             0
# 1        1   25          182           85             0             1
# 2        1   68          183           73             0             1
# 3        1   58          189           72             0             0
# 4        1   24          183           55             0             1
# 5        1   75          187           78             1             0
# 6        1   77          173           68             0             1
# 7        1   80          171           71             0             0
# 8        0   19          188           59             0             1
# 9        0   26          156           56             0             0
# 10       0   75          165           94             0             1
# 11       0   78          160           67             0             1
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           756 non-null    int64
#  1   Age              756 non-null    int64
#  2   Height (cm)      756 non-null    int64
#  3   Weight (kg)      756 non-null    int64
#  4   Hypertension     756 non-null    int64
#  5   Low pressure     756 non-null    int64
#  6   Diabetes         756 non-null    int64
#  7   Heart condition  756 non-null    int64
#  8   Min              756 non-null    int64
#  9   Max              756 non-null    int64
# dtypes: int64(10)
# memory usage: 59.2 KB

# %%
from sklearn.model_selection import train_test_split
x=train[['Gender','Age','Height (cm)','Weight (kg)','Hypertension','Low pressure','Diabetes','Heart condition']]
#x=train[['Hypertension','Low pressure','Diabetes','Heart condition']]
#y1=train[['Min']]
#y2=train[['Max']]

y=train[['Min','Max']]
#x_train,x_val,y1_train,y1_val=train_test_split(x,y1,test_size=0.33,random_state=42)
#x_train,x_val,y2_train,y2_val=train_test_split(x,y2,test_size=0.33,random_state=42)
x_train,x_val,y_train,y_val=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
print('original tain shape : ',x.shape)

print('x_train shape :',x_train.shape)
print('x_val shape :',x_val.shape)

print('y_train shape :',y_train.shape)
#print('y_val shape :',y_val.shape)

#print('y1_train shape :',y1_train.shape)
#print('y1_val shape :',y1_val.shape)
#print('y2_train shape :',y2_train.shape)
#print('y2_val shape :',y2_val.shape)
# Out:
# original tain shape :  (756, 8)
# x_train shape : (604, 8)
# x_val shape : (152, 8)
# y_train shape : (604, 2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_sc = pd.DataFrame(scaler.fit_transform(x_train), columns=x_train.columns)
x_val_sc = pd.DataFrame(scaler.fit_transform(x_val), columns=x_val.columns)

# %%
# Using sklearn
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() 
  
x_train_n = pd.DataFrame(scaler.fit_transform(x_train_sc), columns=x_train_sc.columns,index=x_train_sc.index)
  
x_val_n = pd.DataFrame(scaler.fit_transform(x_val_sc), columns=x_val_sc.columns,index=x_val_sc.index)

# %%
#from sklearn.preprocessing import StandardScaler

#scaler = StandardScaler()
#x_train_sc = pd.DataFrame(scaler.fit_transform(x_train_n), columns=x_train_n.columns)
#x_val_sc = pd.DataFrame(scaler.fit_transform(x_val_n), columns=x_val_n.columns)

# %%
#linear regression model
#train data
from sklearn.metrics import r2_score, mean_squared_error


model_1=LinearRegression()
#model_2=LinearRegression()

model_1.fit(x_train_n,y_train)
y_predict=model_1.predict(x_val_n)
y_predict=y_predict.round()
y_predict = y_predict.astype(int)
r2_score(y_val, y_predict)
# Out:
# 0.6647976897735393

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

reg_forest_1 = RandomForestRegressor(random_state = 42)
reg_forest_1.fit(x_train_n, y_train) # fit the model

preds_forest_test_y1 = reg_forest_1.predict(x_val_n) 
r2_score(y_val, preds_forest_test_y1)
# Out:
# 0.6340840509912449

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Apply PCA and fit the features selected
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x_train_n)

# Create a DataFrame with the two components
PCA_x_train = pd.DataFrame(principalComponents, columns=['Principal Component 1', 'Principal Component 2'])




# Apply PCA and fit the features selected
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x_val_n)

# Create a DataFrame with the two components
PCA_x_val = pd.DataFrame(principalComponents, columns=['Principal Component 1', 'Principal Component 2'])

# %%
from sklearn.metrics import r2_score, mean_squared_error
model_pca=LinearRegression()


model_pca.fit(PCA_x_train,y_train)
y_predict_pca=model_pca.predict(PCA_x_val)
y_predict_pca=y_predict.round()
y_predict_pca = y_predict_pca.astype(int)


r2_score(y_val, y_predict_pca)
# Out:
# 0.6647976897735393

# %%
#L1 REGULARIZATION
from sklearn import linear_model
from sklearn.metrics import r2_score, mean_squared_error

lasso_reg=linear_model.Lasso(alpha=.199,max_iter=100,tol=.1)
lasso_reg.fit(x_train_n,y_train)
y_predict_lasso= lasso_reg.predict(x_val_n)
r2_score(y_val, y_predict_lasso)
# Out:
# 0.6700945257043813

# %%
#L1 REGULARIZATION
from sklearn.linear_model import Ridge

Ridge_reg = Ridge(alpha=10,max_iter=100,tol=.1)
Ridge_reg.fit(x_train_n, y_train)

y_predict_ridge = Ridge_reg.predict(x_val_n)


from sklearn.metrics import r2_score
r2_score(y_val,y_predict_ridge)
# Out:
# 0.6647480168732157

# %%
#XGB Boost 
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
import xgboost as xgb
model_xgb = XGBRegressor()
model_xgb.fit(x_train_n, y_train)
y_prediction_xgb = model_xgb.predict(x_val_n)
  

r2_score(y_val, y_prediction_xgb)
# Out:
# 0.5547802703728879

# %%
from sklearn.tree import DecisionTreeRegressor

dec_model=DecisionTreeRegressor()
dec_model.fit(x_train_n,y_train)
dec_model.score(x_val_n,y_val)
# Out:
# 0.26245149018070735

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV , GridSearchCV
import pandas as pd
from sklearn.model_selection import train_test_split
#from xgboost import XGBRegressor
#import xgboost as xgb

# %%
params={
   'learning_rate':[.05,.10,.15,.20,.25,.30],
   'max_depth':[3,4,5,6,8,10,12,15],
   'min_child_weight':[1,3,5,7],
   'gamma':[.0,.1,.2,.3,.4] ,
   'colsample_bytree':[.3,.4,.5,.7]
}

# %%
import datetime


def timer(start_time=None):
    if not start_time:
        start_time=datetime.now()
        return start_time
    elif start_time:
       thour,temp_sec=divmod((datetime.now()-start_time).total_seconds,3600) 
       tmin,tsec=divmod(temp_sec,60)
       print('/n time taken :%i hours %i minutes and %s secounds'%(thour,tmin,round(tsec,2)))

# %%
classifier = XGBClassifier()

# %%
random_search=RandomizedSearchCV(classifier,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)

# %%
from datetime import datetime
#start_time=timer(None)
random_search= XGBRegressor()
random_search.fit(x_train_n,y_train)
#timer(start_time)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_predict_xgb2 = random_search.predict(x_val_n)

# %%
from sklearn.metrics import mean_squared_error, r2_score  ## use function score   RMSE

print(r2_score(y_val, y_predict_xgb2))
# Out:
# 0.5547802703728879
