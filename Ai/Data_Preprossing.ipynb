# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head(5)
# Out:
#    Meal_Id      \
# 0  meal_id1
# 1  meal_id2
# 2  meal_id3
# 3  meal_id4
# 4  meal_id5
#
#   Name                                                                            \
# 0  summer squash salad                           ...
# 1  chicken minced salad                          ...
# 2  sweet chilli almonds                          ...
# 3  tricolour salad                               ...
# 4  gluten-free christmas cake                    ...
#
#    catagory      \
# 0  salad
# 1  salad
# 2  chilli
# 3  salad
# 4  cake
#
#   description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               \
# 0  white balsamic vinegar, lemon juice, lemon rin...
# 1  olive oil, chicken mince, garlic (minced), oni...
# 2  almonds whole, egg white, curry leaves, salt, ...
# 3  vinegar, honey/sugar, soy sauce, salt, garlic ...
# 4  christmas dry fruits (pre-soaked), orange zest...
#
#    Veg_Non   Nutrient        \
# 0  veg       fiber
# 1  non-veg   fiber
# 2  veg       vitamin_a
# 3  veg       fiber
# 4  veg       vitamin_a
#
#   Disease                                                                                                                 \
# 0  obesity diabeties hypertension goitre         ...
# 1  anemia pregnancy hypertension rickets goitre k...
# 2  hypertension scurvy heart_disease goitre kidne...
# 3  obesity goitre hypertension                   ...
# 4  goitre kidney_disease                         ...
#
#   Diet                                                                                                                                                                                      \
# 0  alkaline_diet low_fat_diet ketogenic_diet low_...
# 1  low_fat_diet low_carb_diet ketogenic_diet low_...
# 2  alkaline_diet low_fat_diet paleo_diet Mediterr...
# 3  low_fat_diet ketogenic_diet low_sodium_diet hi...
# 4  high_protien_diet                             ...
#
#    Price
# 0    485
# 1    600
# 2    255
# 3    615
# 4    465

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 9 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    --------------  -----
#  0   Meal_Id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   512 non-null    object
#  1   Name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      512 non-null    object
#  2   catagory                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  512 non-null    object
#  3   description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               512 non-null    object
#  4   Veg_Non                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   512 non-null    object
#  5   Nutrient                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  512 non-null    object
#  6   Disease                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   512 non-null    object
#  7   Diet                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      512 non-null    object
#  8   Price                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     512 non-null    int64
# dtypes: int64(1), object(8)
# memory usage: 36.1+ KB

# %%
df.columns = df.columns.str.strip()
n2 = (df['Disease'].str.contains('diabeties')) | (df['Disease'].str.contains('heart_disease')) | (df['Disease'].str.contains('hypertension'))

# %%
df[n2]
# Out:
#          Meal_Id                                               Name  \
# 0    meal_id1     summer squash salad                           ...
# 1    meal_id2     chicken minced salad                          ...
# 2    meal_id3     sweet chilli almonds                          ...
# 3    meal_id4     tricolour salad                               ...
# 6    meal_id7     chocolate nero cookies                        ...
# ..           ...                                                ...
# 506  meal_id304   rice                                          ...
# 508  meal_id306   banana chips                                  ...
# 509  meal_id307   bhurji- egg                                   ...
# 510  meal_id308   flattened rice / pohe                         ...
# 511  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# 0    salad         white balsamic vinegar, lemon juice, lemon rin...
# 1    salad         olive oil, chicken mince, garlic (minced), oni...
# 2    chilli        almonds whole, egg white, curry leaves, salt, ...
# 3    salad         vinegar, honey/sugar, soy sauce, salt, garlic ...
# 6    cookie        almonds, eggs, granulated sugar, bittersweet c...
# ..            ...                                                ...
# 506  rice                                                        ...
# 508  banana        r dried slices of bananas (fruits of herbaceou...
# 509  egg           made using indian spices, onion, tomatoes, gre...
# 510  rice          ible, dehusked rice which is flattened into fl...
# 511  rice          grain made from rice; usually made by heating ...
#
#       Veg_Non        Nutrient  \
# 0    veg       fiber
# 1    non-veg   fiber
# 2    veg       vitamin_a
# 3    veg       fiber
# 6    veg       magnesium
# ..        ...             ...
# 506  veg       carbohydrates
# 508  veg       magnesium
# 509  non-veg   vitamin_a
# 510  veg       carbohydrates
# 511  veg       carbohydrates
#
#                                                Disease  \
# 0    obesity diabeties hypertension goitre         ...
# 1    anemia pregnancy hypertension rickets goitre k...
# 2    hypertension scurvy heart_disease goitre kidne...
# 3    obesity goitre hypertension                   ...
# 6    hypertension heart_disease                    ...
# ..                                                 ...
# 506  obesity diabeties anemia                      ...
# 508  hypertension                                  ...
# 509  hypertension rickets goitre kidney_disease pre...
# 510  anemia cancer scurvy heart_disease eye_disease...
# 511  obesity diabeties anemia                      ...
#
#                                                   Diet  Price
# 0    alkaline_diet low_fat_diet ketogenic_diet low_...    485
# 1    low_fat_diet low_carb_diet ketogenic_diet low_...    600
# 2    alkaline_diet low_fat_diet paleo_diet Mediterr...    255
# 3    low_fat_diet ketogenic_diet low_sodium_diet hi...    615
# 6    high_protien_diet high_fiber_diet ketogenic_di...    475
# ..                                                 ...    ...
# 506  high_protien_diet vegan_diet dash_diet ketogen...    350
# 508  alkaline_diet high_protien_diet vegan_diet hig...    295
# 509  low_sodium_diet high_protien_diet low_fat_diet...    645
# 510  alkaline_diet low_fat_diet ketogenic_diet vega...    525
# 511  high_protien_diet vegan_diet dash_diet ketogen...    265
#
# [315 rows x 9 columns]

# %%
df=df[n2]

# %%
df = pd.read_csv('finaldata.csv')
df
# Out:
#            Meal_Id      \
# 0       0  meal_id1
# 1       1  meal_id2
# 2       2  meal_id3
# 3       3  meal_id4
# 4       6  meal_id7
# ..    ...          ...
# 310   506  meal_id304
# 311   508  meal_id306
# 312   509  meal_id307
# 313   510  meal_id308
# 314   511  meal_id309
#
#     Name                                                                            \
# 0    summer squash salad                           ...
# 1    chicken minced salad                          ...
# 2    sweet chilli almonds                          ...
# 3    tricolour salad                               ...
# 4    chocolate nero cookies                        ...
# ..                                                 ...
# 310  rice                                          ...
# 311  banana chips                                  ...
# 312  bhurji- egg                                   ...
# 313  flattened rice / pohe                         ...
# 314  puffed rice                                   ...
#
#      catagory      \
# 0    salad
# 1    salad
# 2    chilli
# 3    salad
# 4    cookie
# ..            ...
# 310  rice
# 311  banana
# 312  egg
# 313  rice
# 314  rice
#
#     description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               \
# 0    white balsamic vinegar, lemon juice, lemon rin...
# 1    olive oil, chicken mince, garlic (minced), oni...
# 2    almonds whole, egg white, curry leaves, salt, ...
# 3    vinegar, honey/sugar, soy sauce, salt, garlic ...
# 4    almonds, eggs, granulated sugar, bittersweet c...
# ..                                                 ...
# 310  riety of rice.                                ...
# 311  r dried slices of bananas (fruits of herbaceou...
# 312  made using indian spices, onion, tomatoes, gre...
# 313  ible, dehusked rice which is flattened into fl...
# 314  grain made from rice; usually made by heating ...
#
#      Veg_Non   Nutrient        \
# 0    veg       fiber
# 1    non-veg   fiber
# 2    veg       vitamin_a
# 3    veg       fiber
# 4    veg       magnesium
# ..        ...             ...
# 310  veg       carbohydrates
# 311  veg       magnesium
# 312  non-veg   vitamin_a
# 313  veg       carbohydrates
# 314  veg       carbohydrates
#
#     Disease                                                                                                                 \
# 0    obesity diabeties hypertension goitre         ...
# 1    anemia pregnancy hypertension rickets goitre k...
# 2    hypertension scurvy heart_disease goitre kidne...
# 3    obesity goitre hypertension                   ...
# 4    hypertension heart_disease                    ...
# ..                                                 ...
# 310  obesity diabeties anemia                      ...
# 311  hypertension                                  ...
# 312  hypertension rickets goitre kidney_disease pre...
# 313  anemia cancer scurvy heart_disease eye_disease...
# 314  obesity diabeties anemia                      ...
#
#     Diet                                                                                                                                                                                      \
# 0    alkaline_diet low_fat_diet ketogenic_diet low_...
# 1    low_fat_diet low_carb_diet ketogenic_diet low_...
# 2    alkaline_diet low_fat_diet paleo_diet Mediterr...
# 3    low_fat_diet ketogenic_diet low_sodium_diet hi...
# 4    high_protien_diet high_fiber_diet ketogenic_di...
# ..                                                 ...
# 310  high_protien_diet vegan_diet dash_diet ketogen...
# 311  alkaline_diet high_protien_diet vegan_diet hig...
# 312  low_sodium_diet high_protien_diet low_fat_diet...
# 313  alkaline_diet low_fat_diet ketogenic_diet vega...
# 314  high_protien_diet vegan_diet dash_diet ketogen...
#
#      Price
# 0      485
# 1      600
# 2      255
# 3      615
# 4      475
# ..     ...
# 310    350
# 311    295
# 312    645
# 313    525
# 314    265
#
# [315 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315 entries, 0 to 314
# Data columns (total 10 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    --------------  -----
#  0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             315 non-null    int64
#  1   Meal_Id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   315 non-null    object
#  2   Name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      315 non-null    object
#  3   catagory                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  315 non-null    object
#  4   description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               315 non-null    object
#  5   Veg_Non                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   315 non-null    object
#  6   Nutrient                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  315 non-null    object
#  7   Disease                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   315 non-null    object
#  8   Diet                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      315 non-null    object
#  9   Price                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     315 non-null    int64
# dtypes: int64(2), object(8)
# memory usage: 24.7+ KB

# %%
df=df.reset_index()

# %%
df.drop('index', inplace=True, axis=1)

# %%
df.columns = df.columns.str.strip()
df['diabeties'] = df['Disease'].str.contains('diabeties')
df['heart_disease'] = df['Disease'].str.contains('heart_disease')
df['hypertension'] = df['Disease'].str.contains('hypertension')
df
# Out:
#               Meal_Id                                               Name  \
# 0      0  meal_id1     summer squash salad                           ...
# 1      1  meal_id2     chicken minced salad                          ...
# 2      2  meal_id3     sweet chilli almonds                          ...
# 3      3  meal_id4     tricolour salad                               ...
# 4      6  meal_id7     chocolate nero cookies                        ...
# ..   ...          ...                                                ...
# 310  506  meal_id304   rice                                          ...
# 311  508  meal_id306   banana chips                                  ...
# 312  509  meal_id307   bhurji- egg                                   ...
# 313  510  meal_id308   flattened rice / pohe                         ...
# 314  511  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# 0    salad         white balsamic vinegar, lemon juice, lemon rin...
# 1    salad         olive oil, chicken mince, garlic (minced), oni...
# 2    chilli        almonds whole, egg white, curry leaves, salt, ...
# 3    salad         vinegar, honey/sugar, soy sauce, salt, garlic ...
# 4    cookie        almonds, eggs, granulated sugar, bittersweet c...
# ..            ...                                                ...
# 310  rice          riety of rice.                                ...
# 311  banana        r dried slices of bananas (fruits of herbaceou...
# 312  egg           made using indian spices, onion, tomatoes, gre...
# 313  rice          ible, dehusked rice which is flattened into fl...
# 314  rice          grain made from rice; usually made by heating ...
#
#       Veg_Non        Nutrient  \
# 0    veg       fiber
# 1    non-veg   fiber
# 2    veg       vitamin_a
# 3    veg       fiber
# 4    veg       magnesium
# ..        ...             ...
# 310  veg       carbohydrates
# 311  veg       magnesium
# 312  non-veg   vitamin_a
# 313  veg       carbohydrates
# 314  veg       carbohydrates
#
#                                                Disease  \
# 0    obesity diabeties hypertension goitre         ...
# 1    anemia pregnancy hypertension rickets goitre k...
# 2    hypertension scurvy heart_disease goitre kidne...
# 3    obesity goitre hypertension                   ...
# 4    hypertension heart_disease                    ...
# ..                                                 ...
# 310  obesity diabeties anemia                      ...
# 311  hypertension                                  ...
# 312  hypertension rickets goitre kidney_disease pre...
# 313  anemia cancer scurvy heart_disease eye_disease...
# 314  obesity diabeties anemia                      ...
#
#                                                   Diet  Price  diabeties  \
# 0    alkaline_diet low_fat_diet ketogenic_diet low_...    485       True
# 1    low_fat_diet low_carb_diet ketogenic_diet low_...    600      False
# 2    alkaline_diet low_fat_diet paleo_diet Mediterr...    255      False
# 3    low_fat_diet ketogenic_diet low_sodium_diet hi...    615      False
# 4    high_protien_diet high_fiber_diet ketogenic_di...    475      False
# ..                                                 ...    ...        ...
# 310  high_protien_diet vegan_diet dash_diet ketogen...    350       True
# 311  alkaline_diet high_protien_diet vegan_diet hig...    295      False
# 312  low_sodium_diet high_protien_diet low_fat_diet...    645       True
# 313  alkaline_diet low_fat_diet ketogenic_diet vega...    525       True
# 314  high_protien_diet vegan_diet dash_diet ketogen...    265       True
#
#      heart_disease  hypertension
# 0            False          True
# 1            False          True
# 2             True          True
# 3            False          True
# 4             True          True
# ..             ...           ...
# 310          False         False
# 311          False          True
# 312          False          True
# 313           True         False
# 314          False         False
#
# [315 rows x 13 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Sample categorical data

# Create an instance of LabelEncoder
encoder = LabelEncoder()

# Fit and transform the data
df['diabeties'] = encoder.fit_transform(df['diabeties'])
df['heart_disease'] = encoder.fit_transform(df['heart_disease'])
df['hypertension'] = encoder.fit_transform(df['hypertension'])
df
# Out:
#               Meal_Id                                               Name  \
# 0      0  meal_id1     summer squash salad                           ...
# 1      1  meal_id2     chicken minced salad                          ...
# 2      2  meal_id3     sweet chilli almonds                          ...
# 3      3  meal_id4     tricolour salad                               ...
# 4      6  meal_id7     chocolate nero cookies                        ...
# ..   ...          ...                                                ...
# 310  506  meal_id304   rice                                          ...
# 311  508  meal_id306   banana chips                                  ...
# 312  509  meal_id307   bhurji- egg                                   ...
# 313  510  meal_id308   flattened rice / pohe                         ...
# 314  511  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# 0    salad         white balsamic vinegar, lemon juice, lemon rin...
# 1    salad         olive oil, chicken mince, garlic (minced), oni...
# 2    chilli        almonds whole, egg white, curry leaves, salt, ...
# 3    salad         vinegar, honey/sugar, soy sauce, salt, garlic ...
# 4    cookie        almonds, eggs, granulated sugar, bittersweet c...
# ..            ...                                                ...
# 310  rice          riety of rice.                                ...
# 311  banana        r dried slices of bananas (fruits of herbaceou...
# 312  egg           made using indian spices, onion, tomatoes, gre...
# 313  rice          ible, dehusked rice which is flattened into fl...
# 314  rice          grain made from rice; usually made by heating ...
#
#       Veg_Non        Nutrient  \
# 0    veg       fiber
# 1    non-veg   fiber
# 2    veg       vitamin_a
# 3    veg       fiber
# 4    veg       magnesium
# ..        ...             ...
# 310  veg       carbohydrates
# 311  veg       magnesium
# 312  non-veg   vitamin_a
# 313  veg       carbohydrates
# 314  veg       carbohydrates
#
#                                                Disease  \
# 0    obesity diabeties hypertension goitre         ...
# 1    anemia pregnancy hypertension rickets goitre k...
# 2    hypertension scurvy heart_disease goitre kidne...
# 3    obesity goitre hypertension                   ...
# 4    hypertension heart_disease                    ...
# ..                                                 ...
# 310  obesity diabeties anemia                      ...
# 311  hypertension                                  ...
# 312  hypertension rickets goitre kidney_disease pre...
# 313  anemia cancer scurvy heart_disease eye_disease...
# 314  obesity diabeties anemia                      ...
#
#                                                   Diet  Price  diabeties  \
# 0    alkaline_diet low_fat_diet ketogenic_diet low_...    485          1
# 1    low_fat_diet low_carb_diet ketogenic_diet low_...    600          0
# 2    alkaline_diet low_fat_diet paleo_diet Mediterr...    255          0
# 3    low_fat_diet ketogenic_diet low_sodium_diet hi...    615          0
# 4    high_protien_diet high_fiber_diet ketogenic_di...    475          0
# ..                                                 ...    ...        ...
# 310  high_protien_diet vegan_diet dash_diet ketogen...    350          1
# 311  alkaline_diet high_protien_diet vegan_diet hig...    295          0
# 312  low_sodium_diet high_protien_diet low_fat_diet...    645          1
# 313  alkaline_diet low_fat_diet ketogenic_diet vega...    525          1
# 314  high_protien_diet vegan_diet dash_diet ketogen...    265          1
#
#      heart_disease  hypertension
# 0                0             1
# 1                0             1
# 2                1             1
# 3                0             1
# 4                1             1
# ..             ...           ...
# 310              0             0
# 311              0             1
# 312              0             1
# 313              1             0
# 314              0             0
#
# [315 rows x 13 columns]

# %%
df.drop('Disease', inplace=True, axis=1)
df.drop('Price', inplace=True, axis=1)

df
# Out:
#               Meal_Id                                               Name  \
# 0      0  meal_id1     summer squash salad                           ...
# 1      1  meal_id2     chicken minced salad                          ...
# 2      2  meal_id3     sweet chilli almonds                          ...
# 3      3  meal_id4     tricolour salad                               ...
# 4      6  meal_id7     chocolate nero cookies                        ...
# ..   ...          ...                                                ...
# 310  506  meal_id304   rice                                          ...
# 311  508  meal_id306   banana chips                                  ...
# 312  509  meal_id307   bhurji- egg                                   ...
# 313  510  meal_id308   flattened rice / pohe                         ...
# 314  511  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# 0    salad         white balsamic vinegar, lemon juice, lemon rin...
# 1    salad         olive oil, chicken mince, garlic (minced), oni...
# 2    chilli        almonds whole, egg white, curry leaves, salt, ...
# 3    salad         vinegar, honey/sugar, soy sauce, salt, garlic ...
# 4    cookie        almonds, eggs, granulated sugar, bittersweet c...
# ..            ...                                                ...
# 310  rice          riety of rice.                                ...
# 311  banana        r dried slices of bananas (fruits of herbaceou...
# 312  egg           made using indian spices, onion, tomatoes, gre...
# 313  rice          ible, dehusked rice which is flattened into fl...
# 314  rice          grain made from rice; usually made by heating ...
#
#       Veg_Non        Nutrient  \
# 0    veg       fiber
# 1    non-veg   fiber
# 2    veg       vitamin_a
# 3    veg       fiber
# 4    veg       magnesium
# ..        ...             ...
# 310  veg       carbohydrates
# 311  veg       magnesium
# 312  non-veg   vitamin_a
# 313  veg       carbohydrates
# 314  veg       carbohydrates
#
#                                                   Diet  diabeties  \
# 0    alkaline_diet low_fat_diet ketogenic_diet low_...          1
# 1    low_fat_diet low_carb_diet ketogenic_diet low_...          0
# 2    alkaline_diet low_fat_diet paleo_diet Mediterr...          0
# 3    low_fat_diet ketogenic_diet low_sodium_diet hi...          0
# 4    high_protien_diet high_fiber_diet ketogenic_di...          0
# ..                                                 ...        ...
# 310  high_protien_diet vegan_diet dash_diet ketogen...          1
# 311  alkaline_diet high_protien_diet vegan_diet hig...          0
# 312  low_sodium_diet high_protien_diet low_fat_diet...          1
# 313  alkaline_diet low_fat_diet ketogenic_diet vega...          1
# 314  high_protien_diet vegan_diet dash_diet ketogen...          1
#
#      heart_disease  hypertension
# 0                0             1
# 1                0             1
# 2                1             1
# 3                0             1
# 4                1             1
# ..             ...           ...
# 310              0             0
# 311              0             1
# 312              0             1
# 313              1             0
# 314              0             0
#
# [315 rows x 11 columns]

# %%
df['press low']=df['hypertension'].apply(lambda x: False if x else True)

# %%
df
# Out:
#               Meal_Id                                               Name  \
# 0      0  meal_id1     summer squash salad                           ...
# 1      1  meal_id2     chicken minced salad                          ...
# 2      2  meal_id3     sweet chilli almonds                          ...
# 3      3  meal_id4     tricolour salad                               ...
# 4      6  meal_id7     chocolate nero cookies                        ...
# ..   ...          ...                                                ...
# 310  506  meal_id304   rice                                          ...
# 311  508  meal_id306   banana chips                                  ...
# 312  509  meal_id307   bhurji- egg                                   ...
# 313  510  meal_id308   flattened rice / pohe                         ...
# 314  511  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# 0    salad         white balsamic vinegar, lemon juice, lemon rin...
# 1    salad         olive oil, chicken mince, garlic (minced), oni...
# 2    chilli        almonds whole, egg white, curry leaves, salt, ...
# 3    salad         vinegar, honey/sugar, soy sauce, salt, garlic ...
# 4    cookie        almonds, eggs, granulated sugar, bittersweet c...
# ..            ...                                                ...
# 310  rice          riety of rice.                                ...
# 311  banana        r dried slices of bananas (fruits of herbaceou...
# 312  egg           made using indian spices, onion, tomatoes, gre...
# 313  rice          ible, dehusked rice which is flattened into fl...
# 314  rice          grain made from rice; usually made by heating ...
#
#       Veg_Non        Nutrient  \
# 0    veg       fiber
# 1    non-veg   fiber
# 2    veg       vitamin_a
# 3    veg       fiber
# 4    veg       magnesium
# ..        ...             ...
# 310  veg       carbohydrates
# 311  veg       magnesium
# 312  non-veg   vitamin_a
# 313  veg       carbohydrates
# 314  veg       carbohydrates
#
#                                                   Diet  diabeties  \
# 0    alkaline_diet low_fat_diet ketogenic_diet low_...          1
# 1    low_fat_diet low_carb_diet ketogenic_diet low_...          0
# 2    alkaline_diet low_fat_diet paleo_diet Mediterr...          0
# 3    low_fat_diet ketogenic_diet low_sodium_diet hi...          0
# 4    high_protien_diet high_fiber_diet ketogenic_di...          0
# ..                                                 ...        ...
# 310  high_protien_diet vegan_diet dash_diet ketogen...          1
# 311  alkaline_diet high_protien_diet vegan_diet hig...          0
# 312  low_sodium_diet high_protien_diet low_fat_diet...          1
# 313  alkaline_diet low_fat_diet ketogenic_diet vega...          1
# 314  high_protien_diet vegan_diet dash_diet ketogen...          1
#
#      heart_disease  hypertension  press low
# 0                0             1      False
# 1                0             1      False
# 2                1             1      False
# 3                0             1      False
# 4                1             1      False
# ..             ...           ...        ...
# 310              0             0       True
# 311              0             1      False
# 312              0             1      False
# 313              1             0       True
# 314              0             0       True
#
# [315 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Sample categorical data

# Create an instance of LabelEncoder
encoder = LabelEncoder()

# Fit and transform the data
df['press low'] = encoder.fit_transform(df['press low'])

df
# Out:
#               Meal_Id                                               Name  \
# 0      0  meal_id1     summer squash salad                           ...
# 1      1  meal_id2     chicken minced salad                          ...
# 2      2  meal_id3     sweet chilli almonds                          ...
# 3      3  meal_id4     tricolour salad                               ...
# 4      6  meal_id7     chocolate nero cookies                        ...
# ..   ...          ...                                                ...
# 310  506  meal_id304   rice                                          ...
# 311  508  meal_id306   banana chips                                  ...
# 312  509  meal_id307   bhurji- egg                                   ...
# 313  510  meal_id308   flattened rice / pohe                         ...
# 314  511  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# 0    salad         white balsamic vinegar, lemon juice, lemon rin...
# 1    salad         olive oil, chicken mince, garlic (minced), oni...
# 2    chilli        almonds whole, egg white, curry leaves, salt, ...
# 3    salad         vinegar, honey/sugar, soy sauce, salt, garlic ...
# 4    cookie        almonds, eggs, granulated sugar, bittersweet c...
# ..            ...                                                ...
# 310  rice          riety of rice.                                ...
# 311  banana        r dried slices of bananas (fruits of herbaceou...
# 312  egg           made using indian spices, onion, tomatoes, gre...
# 313  rice          ible, dehusked rice which is flattened into fl...
# 314  rice          grain made from rice; usually made by heating ...
#
#       Veg_Non        Nutrient  \
# 0    veg       fiber
# 1    non-veg   fiber
# 2    veg       vitamin_a
# 3    veg       fiber
# 4    veg       magnesium
# ..        ...             ...
# 310  veg       carbohydrates
# 311  veg       magnesium
# 312  non-veg   vitamin_a
# 313  veg       carbohydrates
# 314  veg       carbohydrates
#
#                                                   Diet  diabeties  \
# 0    alkaline_diet low_fat_diet ketogenic_diet low_...          1
# 1    low_fat_diet low_carb_diet ketogenic_diet low_...          0
# 2    alkaline_diet low_fat_diet paleo_diet Mediterr...          0
# 3    low_fat_diet ketogenic_diet low_sodium_diet hi...          0
# 4    high_protien_diet high_fiber_diet ketogenic_di...          0
# ..                                                 ...        ...
# 310  high_protien_diet vegan_diet dash_diet ketogen...          1
# 311  alkaline_diet high_protien_diet vegan_diet hig...          0
# 312  low_sodium_diet high_protien_diet low_fat_diet...          1
# 313  alkaline_diet low_fat_diet ketogenic_diet vega...          1
# 314  high_protien_diet vegan_diet dash_diet ketogen...          1
#
#      heart_disease  hypertension  press low
# 0                0             1          0
# 1                0             1          0
# 2                1             1          0
# 3                0             1          0
# 4                1             1          0
# ..             ...           ...        ...
# 310              0             0          1
# 311              0             1          0
# 312              0             1          0
# 313              1             0          1
# 314              0             0          1
#
# [315 rows x 12 columns]

# %%
df['Calories']=np.NaN
df
# Out:
#               Meal_Id                                               Name  \
# 0      0  meal_id1     summer squash salad                           ...
# 1      1  meal_id2     chicken minced salad                          ...
# 2      2  meal_id3     sweet chilli almonds                          ...
# 3      3  meal_id4     tricolour salad                               ...
# 4      6  meal_id7     chocolate nero cookies                        ...
# ..   ...          ...                                                ...
# 310  506  meal_id304   rice                                          ...
# 311  508  meal_id306   banana chips                                  ...
# 312  509  meal_id307   bhurji- egg                                   ...
# 313  510  meal_id308   flattened rice / pohe                         ...
# 314  511  meal_id309   puffed rice                                   ...
#
#          catagory                                        description  \
# 0    salad         white balsamic vinegar, lemon juice, lemon rin...
# 1    salad         olive oil, chicken mince, garlic (minced), oni...
# 2    chilli        almonds whole, egg white, curry leaves, salt, ...
# 3    salad         vinegar, honey/sugar, soy sauce, salt, garlic ...
# 4    cookie        almonds, eggs, granulated sugar, bittersweet c...
# ..            ...                                                ...
# 310  rice          riety of rice.                                ...
# 311  banana        r dried slices of bananas (fruits of herbaceou...
# 312  egg           made using indian spices, onion, tomatoes, gre...
# 313  rice          ible, dehusked rice which is flattened into fl...
# 314  rice          grain made from rice; usually made by heating ...
#
#       Veg_Non        Nutrient  \
# 0    veg       fiber
# 1    non-veg   fiber
# 2    veg       vitamin_a
# 3    veg       fiber
# 4    veg       magnesium
# ..        ...             ...
# 310  veg       carbohydrates
# 311  veg       magnesium
# 312  non-veg   vitamin_a
# 313  veg       carbohydrates
# 314  veg       carbohydrates
#
#                                                   Diet  diabeties  \
# 0    alkaline_diet low_fat_diet ketogenic_diet low_...          1
# 1    low_fat_diet low_carb_diet ketogenic_diet low_...          0
# 2    alkaline_diet low_fat_diet paleo_diet Mediterr...          0
# 3    low_fat_diet ketogenic_diet low_sodium_diet hi...          0
# 4    high_protien_diet high_fiber_diet ketogenic_di...          0
# ..                                                 ...        ...
# 310  high_protien_diet vegan_diet dash_diet ketogen...          1
# 311  alkaline_diet high_protien_diet vegan_diet hig...          0
# 312  low_sodium_diet high_protien_diet low_fat_diet...          1
# 313  alkaline_diet low_fat_diet ketogenic_diet vega...          1
# 314  high_protien_diet vegan_diet dash_diet ketogen...          1
#
#      heart_disease  hypertension  press low  Calories
# 0                0             1          0       NaN
# 1                0             1          0       NaN
# 2                1             1          0       NaN
# 3                0             1          0       NaN
# 4                1             1          0       NaN
# ..             ...           ...        ...       ...
# 310              0             0          1       NaN
# 311              0             1          0       NaN
# 312              0             1          0       NaN
# 313              1             0          1       NaN
# 314              0             0          1       NaN
#
# [315 rows x 13 columns]

# %%
ingrediants={''}
for i in df['description']:
    word=i.split(", ")
    #print(word)
    
    ingrediants.update(word)
for j in ingrediants:
    print(j)
# Out:
# red onion
# paprika
# freshly ground pepper
# refined oil
# Pure Maple Syrup
# sweet chili sauce
#
# anise (whole)
# chilli sauce
# eggs (lightly beaten)
# butchery bag
# beer
# ginger and garlic
# kasundi (Bengali mustard sauce)
# rose essence or vanilla essence
# rum
# Vanilla Essence
# ham slices
# dark chocolate
# mint leaf (crushed nuts
# as they absorb water
# vanilla bean
# made using indian spices
# Green Chillies
# mawa
# sour cream
# fresh coriander
# clove
# khaand (a sweetening agent and a healthier substitute of sugar)
# Cardamom Powder
# currants; golden raisins; dark raisins (each)
# shallots
# Water
# oats flour
# berries
# ginger garlic paste
# fennel powder
# Egg
# curry leaves
# parsley
# parmesan cheese
# almonds whole
# Flour
# caster sugar
# Vanilla Extract
# black cardamom seeds
# carrots (roughly quartered)
# nuscovado sugar (you can also use normal sugar)
# 10 ml potato starch
# lemon slices (1/8 inch thick)
# ground cumin
# poha
# tamarind extract
# seedless dates
# yam beans
# olive oil (for grilling)
# pistachios (blanched)
# cloves
# kiwi
# raw papaya
# Fillet fish
# dehusked rice which is flattened into flat light dry flakes
# for sugar syrup:
# one can of sweetened condensed milk
# flax or chia seeds
# coriander
# zucchini (cut in to 3 cm cubes)
# olive oil
# oil
# cardamom
# whole red chilli (sabut laal mirch)
# Jasmine rice (cooked)
# raspberry puree
# one 9 x 13 inch layer of red velvet cakcake
# red onions
# spinach
# celery leaves
# chicken stock/broth
# poppy seeds (khus-khus)
# lecite
# ground cardamom
# himalayan pink salt / rock salt
# almonds
# salt & pepper
# White Wine
# mint leaves
# all-purpose flour
# plain flour
# spring onion
# salt
# Quinoa (cooked)
# fresh cream
# 1/2 tsp breakfast sugar
# cardamom powder
# american corn kernels
# mustard seeds (sarson)
# kiwifruiit
# cinnamon
# almonds (slivered
# Degi Red Chilli Powder
# honey or maple syrup
# hara chana)
# olives Oil
# cashews (kaju)
# fresh coriander leaves
# strawberries
# pistachio
# goat cheese
# tabasco
# whole wheat flour
# Rolled Oats
# for namak para:
# Curry Leaves
# breakfast sugar
# chaat masala
# vanilla pod
# butter biscuits (broken into pieces)
#  mullet bottarga (optional; see note)
# chinese rice wine
# fresh cilantro
# for hazelnut white chocolate pressed sable:
# cocoa
# chia seeds
# mace powder
# extra virgin olive oil
# oil (for frying)
# kosher salt
# ripe banana
# sugar syrup/gur (jaggery) syrup
# soybean
# chick peas
# cooking oil
# orange peel
# garam masala
# heavy cream
# cornflour
# ground white pepper (kali mirch)
# fresh breadcrumbs
# lime juice
# Garlic Flakes
#  spaghetti
# french beans
# butter (to rub)
# Chocolate Sponge Eggless
# butter
# green apple
# Garlic Cloves
# Flax or Chia Seeds
# goan rice
# sunflower seeds
# artichoke hearts
# fresh mint leaves
# chili flakes
# Red Rice Vermicelli/ Broken Semolina/ Sooji Vermicelli
# chana dal
# cookes peas
# oil
# blueberries
# for flexy berry:
# finger millet flour (ragi)
# all-purpose gluten free flour
# 20 gm porcini
# coriander
# peanut oil
# salt and black pepper
# soya sauce
# salt
# salt or rock salt
# pandan leaf
# flax seeds
# garlic (minced)
# whole chilli
# Sole fish
# cinnamon stick
# chives
# big lemon
# whisky
# nutmeg powder
# fresh pineapple
# Ginger Garlic
# ground cinnamon
# Berries
# potato (grated)
# raw banana paste
# olive oil
# basmati rice (soaked in water)
# fresh turmeric
# Wheat flour
# litchis (deseeded)
# green chilles
# lemon. pieces of
# green cardamom pod
# elaichi
# soft dried figs
# salt
# saffron strands / thread
# dry fruits
# chocolate chips
# rose water
# bread slices
# jaggery
# Coriander Powder
# ible
# tortilla sheet
# instant espresso (mixed with 1 tbsp water)
# black cardamom
# grapes
# yams (red skinned)
# gorka
# pure vanilla extract
# icing sugar
# whole milk
# red chillies
# and had with bread
# black gram (kala chana)
# lemon juice
# whole free range chicken
# ground black pepper
# walnuts
# toasted almonds (powdered)
# black peppercorns (crushed)
# powdered turmeric
# jamun
# cooked rice
# bell pepper (saut�ed and diced)
# 50 ml oil
# Garam Masala Powder
# water
# small bunch parsley
# salt
# raw rice
# garlic clove
# rock salt
# Cloves
# Butter
# all spice powder
# whole chicken
# milk (warm)
# red grapes
# for hazelnut streusel:
# fish fillet
# almond powder
# peeled and sliced apple
# core
# lemon rind
# jalapeno poppers
# these flakes of rice swell when added to liquid
# clarified butter (desi ghee)
# coffee
# black mustard seeds
# young corn on the cob
# black pepper corns
# turmeric powder
# Green Coriander
# Red rice
# egg yolks +  whole eggs
# crush mix chilli
# paan (crushed)
# Oats
# chilli
# tomatoes (diced)
# lotus root
# lemon (for lemon juice)
# dijon mustard
# soya chunks
# sweetener (optional)
# poppy seeds
# caramel sauce
# almonds (whole)
# caster sugar
# with curry
# turnip
# garlic pods
# black olive tapenade
# Basmati rice
# basil leaves
# anardana
# onions
# vanilla flavoured yogurt (low fat)
# large shrimps (optional)
# fish fillet (pomfret (or any white fish)
# celery
# cashews
# salt
# green cardamom powder
# olive oil (regular not extra virgin)
# apple cider
# Olive oil
# cumin seed
# canola oil
# white wine
# tomato sauce
# cashew nuts
# popped amaranth seeds
# Coriander
# green chili
# chawli
# Spinach
# ginger and garlic paste
# Cadbury Gems
# plain yogurt
# Chicken breast
# seabass fish curry cuts
# asafoetida
# raw mango (pieces)
# mascarpone
# cardamom (elaichi) powder
# Minced lamb
# refined flour (for rolling)
# apples
# khoya
# drumstick
# endive lettuce
# green papaya
# mock meat
# mozzarella cheese
# water
# Cream
# iceberg lettuce
# honey/sugar
# Green Chilli
# edamame beans
# cocoa powder
# Camel Milk
# fresh green chillies (deseeded)
# coriander powder
# coriander leaves
# mango flesh
# Core
# icing sugar
# soya sauce
# assam tea bags
# thai ginger
# Cinnamon
# maple syrup
# gram flour (besan)
# apple
# nutmeg
# organic all-purpose flour
# sweet paprika
# Chicken
# fresh basil leaves
# white chocolate
# blueberries
# cashews (kaju)
# oil
# Apples
# lemon (juiced)
# lobster meat
#
# red and yellow capsicum
# sugar
# lime (juiced)
# yeast
# chicken breast supremes
# for garnish:
# riety of rice
# melted white chocolate
# red food coloring
#  parsley
# potatoes (peeled)
# Sweet potato cubes
# somtam dressing
# Rice
# Pineapple Chunks
# green chilies
# almonds and pistachios
# cinnamon sticks
# hoisin sauce
# spring onion
# sugar (ground)
# sweet chilli sauce
# garlic
# dark soy sauce
# potato
# salt
# Peanuts (Crushed)
# green cardamoms
# Ginger Paste
# plain yogurt (whipped with lemon rind)
# red chilli
# Vanilla
# halved
# though the method of manufacture varies widely. pori (puffed rice) has been mentioned in various tamil literatures as an offering to hindu deities. offerings of pori and jaggery made to vinayagar (lord ganesh) are mentioned in the tiruppugazh
# nutmeg (ground)
# Bacon
# red chilli powder
# butter or margarine
# tamarind puree
# chicken thigh/breast (cut crosswise into 1/2-inch-thin strips)
# red lentils or masoor dal (half-boiled)
# rice vinegar
# palm sugar
# instant vanilla pudding mix
# summer squash (zucchini)
# peppercorn
# Bananas
# ginger (mash)
# spring fresh thyme - optional 1 bay leaf
# chicken mince
# Carrot
# ginger paste
# scrubbed
# rice paper sheets
# cinnamon powder
# butter (room temp cut into 1 inch pieces)
# desi ghee
# salt & pepper
# rolled oats
# fenugreek (methi)
# curry powder
# dark chocolate coverture
# coconut
# for chana chaat:
# Whole Milk
# orange juice
# garlic cloves (crushed)
# lobster shell
# Banana
# Salt
# cumin
# onions (quartered- skin on)
# Heavy Cream
# salt
# milk chocolate or dark chocolate
# Cherry Tomatoes
# fresh cherries
# pizza seasoning
# Red Poha
# cinnamon powder
# Turmeric
# turmeric
# few shakes of black pepper
# cashew nuts and almonds
# lamb bones
# fresh orange juice
# coconut oil
# rock salt
# basil leaves
# noodles
# lettuce arugula (trummed)
# fresh lemon juice
# pepper
# garlic (halved - skin on)
# Fish pieces (boneless)
# water.
# refined flour (maida)
# extra olive oil
# almonds (crushed)
# fresh peach slices
# egg whites
# panko
# Peas and French Beans)
# tamarind paste
# tomato
# White Chilli Powder
# curd
# Red Chilli Powder
# raisins
# prunes
# cheddar cheese
# Shiitake mushrooms
# curry leaf
# wilted spinach
# mustard
# carrot (peeled)
# carnaroli rice
# chicken stock
# coconut (tender)
# capsicum
# cooked basmati rice
# hot curry powder
# peeled and sliced pear
#
# urad dal
# rice (washed)
# Maida Organic
# fresh coconut paste
# Hot Curry Powder
# Eggs
# ginger
# sesame seeds
# brown bread slices
# garlic cloves (minced)
# Crushed Mix Chili
# bread (white/brown)
# espresso
# Taco Shell
# Baking Soda
# ka
# basil pesto
# fresh parsley leaves
# icing sugar
# Fresh Turmeric
# parmesan
# marshmallows
# written by tamil poet arunagirinathar. pori is offered to hindu gods and goddesses in all poojas in the south indian states of kerala and tamil nadu.
# wine vinegar
# sole fillet (you can also do 2/3 types of fish)
# zucchini
# Onion
# Lemongrass
# eggs
# lemon juice
# cream
# chana
# Pepper
# coconut
# tamarind (lemon sized)
# Whole almonds
# almonds (halved)
# tarts
# thyme
# Garlic Paste
# ghee
# Black Salt
# dry white wine
# onion (finely diced)
# hot water
# Garlic
# basmati rice (soaked for 2 hours)
# oats
# garlic cloves
# Carrots
# 1/4 cup plus 1 tablespoon extra-virgin olive oil
# fresh coconut
# unpeeled)
# white pepper
# Baking Powder
# prunes (stoned dried)
# chilled water
# Kasuri methi
# dark brown sugar
# kewda to flavor
# red chilli paste
# ginger/galangal
# pectin
# cinnamon jaggery powder
# apple cider vinegar
# mustard seeds
# cream cheese (softened)
# water
#   red pepper
# rohu fish
# avocado (ripened and diced)
# rice wine vinegar
# carrot
# Peanuts
# salmon fillet
# parmesan cheese shavings
# shallot oil
# Stuffed Green Olives
# assorted seasonal fruits
# peanut butter
# fresh coconut
# asparagus
# castor sugar
# asafoetida (heeng)
# coriander seeds
# Vinegar
# garlic powder
# or they can be fried in oil and spices and have a salty and/or spicy taste.[2]
# sugar (fine grain)
# tamarind pulp
# whole red chilli
# fresh corn kernels
# tomato sauce
# dried fish named kolim or jawla found in coastal maharashtra with onion and spices. usually eaten with bhakri or chapati
# black pepper
# cookie crumble
# Cinnamon Powder
# corn flour
# cucumber
# beetroot puree
# peanuts)
# for modak:
# Water
# plus more for drizzling
# onions (cut into slices)
# ginger-garlic paste
# rice flour
# bean stick
# beetroot colour or two oven cooked beetroot paste
# whole chicken (skin on- rinsed and dressed)
# Fresh fish pieces (river sole or sea bass)
# cinnamon
# American corn kernels
# peanuts
# basil
# rice
# bayleaf
# watermelon balls or small squares (seedless)
# mayonnaise
# red onion (optional)
# toasted peanuts
# arborio rice
# turmeric powder
# carrots
# Green Peas
# red cabbage
# vegetable oil
# few dashes of hot sauce
# fish (cubed)
# Onion Paste
# vanilla essence
# green apple
# red capsicum (can use green also)
# Surmai fish
# freshly ground black pepper
# rice
# turmeric powder(haldi)
# Ghee
# whole coriander seeds
# Soy Sauce
# cucumbers
# butter
# ...
# salt to taste
# nuts
# 1 cucumber peeled and chopped
# egg (optional)
# vanilla
# boiling water
# sugar
# low fat yogurt
# besan
# egg yolk
# white bread slices
# vanilla
# gelatin
# paprika and olives powder
# cumin seeds
# semolina (rava/suji)
# coriander leaves
# pepper (freshly ground)
# fresh raspberries
# dessicated coconut
# honey
# butter (chilled)
# curry leaves (kadhi patta)
# cloves (whole)
# white balsamic vinegar
# onions
# oregano
# Milk
#  garlic cloves
# cherry tomato
# tossed flax seeds (for topping)
# saffron (kesar) strands
# King fish
# boiling water
# fenugreek seeds
# matcha powder
# salt
# flour
# active charcoal
# dunkleweizen (pour into a glass and keep open at room temperature for an hour or two to make flat)
# ?Baasa fish
# green chillies
# hazelnut streusel
# Glucose
# Baking Powder
# lobster stock
# fennel seeds (saunf) (crushed coarsely)
# fresh sole fish
# fresh chives (dried if fresh not available)
# n lime and ginger and cooked over an open fire.
# chicken broth
# milk
# egg white
# banana
# pizza/flatbread base
# almonds
# cream cheese (softened and cut into 8 pieces)
# lollo rosso
# black cardamoms
# milk
# cumin (powdered)
# vinegar
#  thyme
# celery (finely diced)
# for sauce: ginger
# ice cold water
# dates (pitted)
# prawns (shelled and cleaned)
# jaggery (organic)
# Pistachios
# Coriander
# edible flower
# pumpkin
# Lemon Juice
# cardamoms
# ghee
# red rice vermicelli / broken sooji / semolina vermicelli
# potato (boiled)
# semolina
# ripe mango (diced)
# fresh raspeberry
# salt
# fresh coriander
# Peanuts
# oil (for greasing)
# ginger juice
# red wine
# ghee or oil
# almonds (chopped)
#
# brown sugar
# Saffron Threads
# basil sprig
# Tuna
# peanuts (to garnish)
# buckwheat flour
# milk or water
# clarified butter
# hollandaise sauce
# thai green curry paste
# Sage Leaf
# coriander (toasted & ground)
# sea salt
# Tomato
# pomegranate
# basil leaves
# mixed dried herbs
# shallots
# fresh buffalo mozzarella cheese
# fresh strawberries
# White chocolate
# fresh parsley (dried if fresh not available)
# avocado paste
# r dried slices of bananas (fruits of herbaceous plants of the genus musa of the soft
# watermelon
# onion (minced)
# ground nut oil
# semolina (rava/sooji)
# for the ratatouille:
# almonds (shredded)
# phyllo sheets
# salt
# broccoli
# rosemary
# cabbage
# sea salt
# liquid glucose
# clove powder
# white wine and water mix to cover
# honey
# small green chilli
# vanilla essence
# ripe bananas
# brandy
# kasha
# garlic
# flour
# ground chickpea flour (sattu)
# black pepper powder
# ajwain
# assorted garden herbs ( parsley
# star anise
# Caster Sugar
# Oil
# salt.
# unsweetened cocoa powder
# chilli powder
# butter (softened)
# sesame seeds or cinnamon)
# lemon (zest and juice)
# almonds (badam) - coarsley crushed
# mixed boiled beans (choose from rajma
# oyster sauce
# or parathas.
# Ginger
# oil (for greasing)
# whole moong beans
# pepper corn
# rice noodles (soaked in warm water for 20-25 minutes)
# green onion
# berry puree
# whole wheat flour or oat flour
# Baking Powder
# unsalted butter (room temperature)
# cassia bark or cinnamon stick
# food thermometer
# ginger and garlic paste.
# quinoa (cooked)
# ginger

# %%
data=pd.read_csv('calories0.csv')
data
# Out:
#       Unnamed: 0                      Ingredient  Calories per 100 grams
# 0              0                     Rolled Oats                     379
# 1              1                           Thyme                       2
# 2              2                   Fresh Parsley                      43
# 3              3                   Dried Parsley                       6
# 4              4             Garam Masala Powder                     323
# ...          ...                             ...                     ...
# 1122        1122  Cornflour (Blended With Water)                     372
# 1123        1123                 Toasted Almonds                     578
# 1124        1124                        Tamarind                      27
# 1125        1125                       Pineapple                      49
# 1126        1126                      Bay leaves                       2
#
# [1127 rows x 3 columns]

# %%
data.drop('Unnamed: 0', inplace=True, axis=1)

# %%
data
# Out:
#                           Ingredient  Calories per 100 grams
# 0                        Rolled Oats                     379
# 1                              Thyme                       2
# 2                      Fresh Parsley                      43
# 3                      Dried Parsley                       6
# 4                Garam Masala Powder                     323
# ...                              ...                     ...
# 1122  Cornflour (Blended With Water)                     372
# 1123                 Toasted Almonds                     578
# 1124                        Tamarind                      27
# 1125                       Pineapple                      49
# 1126                      Bay leaves                       2
#
# [1127 rows x 2 columns]

# %%
data = pd.DataFrame(columns=[data['Ingredient'], data['Calories per 100 grams']])
data
# Out:
# C:\Users\Elewa\AppData\Local\Temp\ipykernel_9600\1571056357.py:1: DeprecationWarning: Series._data is deprecated and will be removed in a future version. Use public APIs instead.
#   data = pd.DataFrame(columns=[data['Ingredient'], data['Calories per 100 grams']])
# C:\Users\Elewa\AppData\Local\Temp\ipykernel_9600\1571056357.py:1: DeprecationWarning: Series._data is deprecated and will be removed in a future version. Use public APIs instead.
#   data = pd.DataFrame(columns=[data['Ingredient'], data['Calories per 100 grams']])
# Empty DataFrame
# Columns: [(Rolled Oats, 379), (Thyme, 2), (Fresh Parsley, 43), (Dried Parsley, 6), (Garam Masala Powder, 323), (Fresh Breadcrumbs, 350), (Egg, 155), (Black Pepper, 250), (Assorted Garden Herbs (Parsley), 43), (Salt, 0), (Kosher Salt, 0), (Red Wine, 50), (Basil Pesto, 120), (Cinnamon Powder, 266), (Pistachios, 562), (Bell Pepper (Saut?ed and Diced), 30), (Dry Fruits, 280), (Fresh Cream, 200), (Khaand (Sweetening Agent), 230), (Red Bell Pepper (Cut into Thin Strips), 31), (Peach Fruit Slices, 49), (Red Capsicum, 31), (Full Cream Milk, 64), (Aamchoor Powder, 2), (Wilted Spinach, 23), (Green Peas, 79), (Tofu, 78), (Sweet Chilli Sauce, 75), (Fish Fillet, 105), (Water, 0), (Toasted Peanuts, 578), (Cardamom Powder, 304), (Green Cardamom Pod, 311), (Dark Rum, 235), (Tempura Batter, 340), (Brown Sugar or Jaggery, 324), (Jaggery, 383), (Strawberries, 32), (Nutmeg Powder, 266), (Cumin Powder, 322), (Bread (White/Brown), 265), (Tamarind (Lemon Sized), 27), (Salt, 0), (Chilli Pepper (Sliced), 40), (Black Pepper Powder, 0), (Black Garlic Pickle, 160), (Apple Cider, 26), (Fresh Pineapple, 49), (Red Velvet Cake (One 9 x 13 Inch Layer), 407), (Chilled Water, 0), (Lemon (For Lemon Juice), 29), (Parmigiano Cheese, 384), (White Wine and Water Mix to Cover, 13), (Cashews (Kaju), 553), (Prawns, 99), (Oil, 119), (Pumpkin, 33), (Sour Curd, 110), (Rice (Washed), 358), (Assorted Seasonal Fruits, 60), (Green Chilli Sauce, 75), (Fresh Cilantro, 27), (Corn Kernels, 102), (Garlic (Halved - Skin On), 149), (Mawa, 269), (Fresh Parsley Leaves, 42), (American Corn Kernels, 102), (Paprika Powder, 43), (Sweet Chili Sauce, 75), (Salt and Pepper, 10), (Mixed Vegetables (Chopped Fine or Grated), 32), (Parathas, 265), (Anardana, 29), (Eggs (Lightly Beaten), 155), (Olive Oil, 119), (French Bread Loaf, 265), (Parmesan, 292), (Mixed Dried Herbs, 2), (Green Chillies (Slit), 40), (Raw Banana Paste, 335), (Green Coriander, 27), (Beetroot Puree, 67), (Green Chilies, 40), (Egg Yolk, 344), (Vanilla, 288), (Quinoa, 368), (Honey or Maple Syrup, 260), (Water, 0), (Chilli, 40), (Dates (Ripe), 277), (Salt, 0), (Green Chillies, 40), (Turnip, 35), (Flax or Chia Seeds, 5), (Coriander Leaves, 27), (Pectin, 300), (Red Cabbage, 25), (Salt, 0), (Almonds and Pistachios, 557), (Bread Flour, 355), ...]
# Index: []
#
# [0 rows x 1127 columns]

# %%
df.to_csv("finally.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\coding\_Python-fundamental\FitSync\Ai\Data_Preprossing.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/coding/_Python-fundamental/FitSync/Ai/Data_Preprossing.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> df.to_csv("finally.csv")
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('finally.csv')
