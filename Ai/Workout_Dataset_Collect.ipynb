# %%
import pandas as pd
import random
import os

# %%
df=pd.read_csv('data/workout/workout_dataset.csv')
df
# Out:
#                                            Exercise Plan ExerciseType  \
# 0            Plank, Lunges, Squats, High Knees, Push-ups       Cardio
# 1      Burpees, Squats, Mountain Climbers, Plank, Pus...       Cardio
# 2      Jumping Jacks, Burpees, Squats, Mountain Climb...  Flexibility
# 3      Push-ups, Lunges, Squats, Mountain Climbers, B...  Flexibility
# 4      Lunges, Burpees, Squats, High Knees, Mountain ...     Strength
# ...                                                  ...          ...
# 19995  Mountain Climbers, High Knees, Lunges, Push-up...  Flexibility
# 19996  Squats, Mountain Climbers, Lunges, Plank, High...       Cardio
# 19997  Squats, Jumping Jacks, Burpees, Plank, High Knees  Flexibility
# 19998  Push-ups, High Knees, Lunges, Plank, Mountain ...     Strength
# 19999  Lunges, Burpees, Push-ups, Mountain Climbers, ...  Flexibility
#
#          Difficulty  Total Plan Duration (minutes)  Calories Burned (Plan)  \
# ...

# %%
df.columns = df.columns.str.strip()
df['Diabetes'] = df['Medical Condition'].str.contains('Diabetes')
df['Heart Disease'] = df['Medical Condition'].str.contains('Heart Disease')
df['Hypertension'] = df['Medical Condition'].str.contains('Hypertension')
df
# Out:
#                                            Exercise Plan ExerciseType  \
# 0            Plank, Lunges, Squats, High Knees, Push-ups       Cardio
# 1      Burpees, Squats, Mountain Climbers, Plank, Pus...       Cardio
# 2      Jumping Jacks, Burpees, Squats, Mountain Climb...  Flexibility
# 3      Push-ups, Lunges, Squats, Mountain Climbers, B...  Flexibility
# 4      Lunges, Burpees, Squats, High Knees, Mountain ...     Strength
# ...                                                  ...          ...
# 19995  Mountain Climbers, High Knees, Lunges, Push-up...  Flexibility
# 19996  Squats, Mountain Climbers, Lunges, Plank, High...       Cardio
# 19997  Squats, Jumping Jacks, Burpees, Plank, High Knees  Flexibility
# 19998  Push-ups, High Knees, Lunges, Plank, Mountain ...     Strength
# 19999  Lunges, Burpees, Push-ups, Mountain Climbers, ...  Flexibility
#
#          Difficulty  Total Plan Duration (minutes)  Calories Burned (Plan)  \
# ...

# %%
df.fillna(0, inplace=True)
df.replace(False, 0, inplace=True)
df.replace(True, 1, inplace=True)
df
# Out:
#                                            Exercise Plan ExerciseType  \
# 0            Plank, Lunges, Squats, High Knees, Push-ups       Cardio
# 1      Burpees, Squats, Mountain Climbers, Plank, Pus...       Cardio
# 2      Jumping Jacks, Burpees, Squats, Mountain Climb...  Flexibility
# 3      Push-ups, Lunges, Squats, Mountain Climbers, B...  Flexibility
# 4      Lunges, Burpees, Squats, High Knees, Mountain ...     Strength
# ...                                                  ...          ...
# 19995  Mountain Climbers, High Knees, Lunges, Push-up...  Flexibility
# 19996  Squats, Mountain Climbers, Lunges, Plank, High...       Cardio
# 19997  Squats, Jumping Jacks, Burpees, Plank, High Knees  Flexibility
# 19998  Push-ups, High Knees, Lunges, Plank, Mountain ...     Strength
# 19999  Lunges, Burpees, Push-ups, Mountain Climbers, ...  Flexibility
#
#          Difficulty  Total Plan Duration (minutes)  Calories Burned (Plan)  \
# ...

# %%
df.drop('Medical Condition', axis=1, inplace=True)
df
# Out:
#                                            Exercise Plan ExerciseType  \
# 0            Plank, Lunges, Squats, High Knees, Push-ups       Cardio
# 1      Burpees, Squats, Mountain Climbers, Plank, Pus...       Cardio
# 2      Jumping Jacks, Burpees, Squats, Mountain Climb...  Flexibility
# 3      Push-ups, Lunges, Squats, Mountain Climbers, B...  Flexibility
# 4      Lunges, Burpees, Squats, High Knees, Mountain ...     Strength
# ...                                                  ...          ...
# 19995  Mountain Climbers, High Knees, Lunges, Push-up...  Flexibility
# 19996  Squats, Mountain Climbers, Lunges, Plank, High...       Cardio
# 19997  Squats, Jumping Jacks, Burpees, Plank, High Knees  Flexibility
# 19998  Push-ups, High Knees, Lunges, Plank, Mountain ...     Strength
# 19999  Lunges, Burpees, Push-ups, Mountain Climbers, ...  Flexibility
#
#          Difficulty  Total Plan Duration (minutes)  Calories Burned (Plan)  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numerical columns
numerical_df = df.select_dtypes(include='number')

# Set the figure size
plt.figure(figsize=(10, 8))

# Plot correlation matrix
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
print("Descriptive Statistics:")
print(numerical_df.describe())

# Check for duplicates
print("Number of duplicate rows: ", numerical_df.duplicated().sum())

# Distribution plots for each feature
for column in numerical_df.columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(numerical_df[column], bins=30, kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()
# Out:
# Descriptive Statistics:
#        Total Plan Duration (minutes)  Calories Burned (Plan)   Height (cm)  \
# count                   20000.000000            20000.000000  20000.000000
# mean                       49.956750              618.403700    174.447000
# std                         9.129679              113.590607     14.400467
# min                        25.000000              408.000000    150.000000
# 25%                        45.000000              520.000000    162.000000
# 50%                        50.000000              620.000000    174.000000
# 75%                        55.000000              700.000000    187.000000
# max                        75.000000              864.000000    200.000000
#
#                 Age   Weight (kg)           BMI    Knee Pain    Back Pain  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.00000
# mean      38.993900     73.749100     24.232137      0.50475      0.49850
# ...

# %%
import numpy as np

# Calculate z-scores for each numerical column
z_scores = (numerical_df - numerical_df.mean()) / numerical_df.std()

# Define a threshold for outlier detection (e.g., z-score > 3 or z-score < -3)
threshold = 3

# Find outliers by checking if the absolute z-score exceeds the threshold
outliers = np.abs(z_scores) > threshold

# Handle outliers by replacing them with NaN or a suitable value
numerical_df[outliers] = np.nan

# Alternatively, you can remove the rows containing outliers
# numerical_df = numerical_df[~outliers.any(axis=1)]

# Fill NaN values with a suitable method (e.g., mean, median, or interpolation)
numerical_df.fillna(numerical_df.mean(), inplace=True)

# Print the updated dataframe
numerical_df
# Out:
#        Total Plan Duration (minutes)  Calories Burned (Plan)  Height (cm)  \
# 0                                 45                   570.0          169
# 1                                 55                   536.0          194
# 2                                 50                   756.0          199
# 3                                 55                   864.0          191
# 4                                 55                   792.0          175
# ...                              ...                     ...          ...
# 19995                             40                   684.0          155
# 19996                             55                   648.0          168
# 19997                             55                   472.0          171
# 19998                             35                   456.0          158
# 19999                             55                   864.0          164
#
#        Age  Weight (kg)        BMI  Knee Pain  Back Pain  Diabetes  \
# ...

# %%
sns.boxplot(data=numerical_df, orient="h")
plt.xlabel("Value")
plt.ylabel("Frequency")
#plt.title("ID")
plt.tight_layout()
plt.show()

# %%
df.to_csv(os.path.join('data', 'workout', 'Workout_Data.csv'))

# %%
df = pd.read_csv(os.path.join('data', 'workout', 'workout_dataset1.csv'))
df.head(5)
# Out:
#                                        Exercise Plan ExerciseType Difficulty  \
# 0  Plank, Lunges, Russian Twists, Burpees, Sit-up...     Strength   Beginner
# 1  Plank, Dumbbell Rows, Jumping Jacks, Lunges, B...       Cardio   Beginner
# 2  Squats, Sit-ups, Calf Raises, Bicep Curls, Leg...  Flexibility   Advanced
# 3  Deadlifts, Bicep Curls, Box Jumps, Plank Jacks...       Cardio   Advanced
# 4  Lateral Raises, Calf Raises, Push-ups, Bench P...  Flexibility   Advanced
#
#    Total Plan Duration (minutes)  Calories Burned (Plan)  \
# 0                             35                   544.0
# 1                             50                   544.0
# 2                             70                   744.0
# 3                             60                   900.0
# 4                             60                   768.0
#
#                                  Target Muscle Group Medical Condition  \
# 0  Core (Abdominals, Lower Back), Quadriceps, Ham...               NaN
# ...

# %%
df.columns = df.columns.str.strip()
df['Diabetes'] = df['Medical Condition'].str.contains('Diabetes')
df['Heart Disease'] = df['Medical Condition'].str.contains('Heart Disease')
df['Hypertension'] = df['Medical Condition'].str.contains('Hypertension')
df.head(5)
# Out:
#                                        Exercise Plan ExerciseType Difficulty  \
# 0  Plank, Lunges, Russian Twists, Burpees, Sit-up...     Strength   Beginner
# 1  Plank, Dumbbell Rows, Jumping Jacks, Lunges, B...       Cardio   Beginner
# 2  Squats, Sit-ups, Calf Raises, Bicep Curls, Leg...  Flexibility   Advanced
# 3  Deadlifts, Bicep Curls, Box Jumps, Plank Jacks...       Cardio   Advanced
# 4  Lateral Raises, Calf Raises, Push-ups, Bench P...  Flexibility   Advanced
#
#    Total Plan Duration (minutes)  Calories Burned (Plan)  \
# 0                             35                   544.0
# 1                             50                   544.0
# 2                             70                   744.0
# 3                             60                   900.0
# 4                             60                   768.0
#
#                                  Target Muscle Group Medical Condition  \
# 0  Core (Abdominals, Lower Back), Quadriceps, Ham...               NaN
# ...

# %%
df.fillna(0, inplace=True)
df.replace(False, 0, inplace=True)
df.replace(True, 1, inplace=True)
df.head(5)
# Out:
#                                        Exercise Plan ExerciseType Difficulty  \
# 0  Plank, Lunges, Russian Twists, Burpees, Sit-up...     Strength   Beginner
# 1  Plank, Dumbbell Rows, Jumping Jacks, Lunges, B...       Cardio   Beginner
# 2  Squats, Sit-ups, Calf Raises, Bicep Curls, Leg...  Flexibility   Advanced
# 3  Deadlifts, Bicep Curls, Box Jumps, Plank Jacks...       Cardio   Advanced
# 4  Lateral Raises, Calf Raises, Push-ups, Bench P...  Flexibility   Advanced
#
#    Total Plan Duration (minutes)  Calories Burned (Plan)  \
# 0                             35                   544.0
# 1                             50                   544.0
# 2                             70                   744.0
# 3                             60                   900.0
# 4                             60                   768.0
#
#                                  Target Muscle Group Medical Condition  \
# 0  Core (Abdominals, Lower Back), Quadriceps, Ham...                 0
# ...

# %%
df.drop('Medical Condition', axis=1, inplace=True)
df.head(5)
# Out:
#                                        Exercise Plan ExerciseType Difficulty  \
# 0  Plank, Lunges, Russian Twists, Burpees, Sit-up...     Strength   Beginner
# 1  Plank, Dumbbell Rows, Jumping Jacks, Lunges, B...       Cardio   Beginner
# 2  Squats, Sit-ups, Calf Raises, Bicep Curls, Leg...  Flexibility   Advanced
# 3  Deadlifts, Bicep Curls, Box Jumps, Plank Jacks...       Cardio   Advanced
# 4  Lateral Raises, Calf Raises, Push-ups, Bench P...  Flexibility   Advanced
#
#    Total Plan Duration (minutes)  Calories Burned (Plan)  \
# 0                             35                   544.0
# 1                             50                   544.0
# 2                             70                   744.0
# 3                             60                   900.0
# 4                             60                   768.0
#
#                                  Target Muscle Group  Gender  Height (cm)  \
# 0  Core (Abdominals, Lower Back), Quadriceps, Ham...  Female          157
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numerical columns
numerical_df = df.select_dtypes(include='number')

# Set the figure size
plt.figure(figsize=(10, 8))

# Plot correlation matrix
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
print("Descriptive Statistics:")
print(numerical_df.describe())

# Check for duplicates
print("Number of duplicate rows: ", numerical_df.duplicated().sum())

# Distribution plots for each feature
for column in numerical_df.columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(numerical_df[column], bins=30, kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()
# Out:
# Descriptive Statistics:
#        Total Plan Duration (minutes)  Calories Burned (Plan)  Height (cm)  \
# count                     400.000000              400.000000   400.000000
# mean                       60.075000              697.105000   174.460000
# std                        10.259509              135.519899    14.700294
# min                        30.000000              408.000000   150.000000
# 25%                        55.000000              584.000000   162.000000
# 50%                        60.000000              690.000000   175.000000
# 75%                        70.000000              792.000000   187.000000
# max                        90.000000             1056.000000   199.000000
#
#               Age  Weight (kg)         BMI  Knee Pain   Back Pain    Diabetes  \
# count  400.000000   400.000000  400.000000  400.00000  400.000000  400.000000
# mean    39.267500    73.772500   24.200928    0.50750    0.465000    0.240000
# ...

# %%
import numpy as np

# Calculate z-scores for each numerical column
z_scores = (numerical_df - numerical_df.mean()) / numerical_df.std()

# Define a threshold for outlier detection (e.g., z-score > 3 or z-score < -3)
threshold = 3

# Find outliers by checking if the absolute z-score exceeds the threshold
outliers = np.abs(z_scores) > threshold

# Handle outliers by replacing them with NaN or a suitable value
numerical_df[outliers] = np.nan

# Alternatively, you can remove the rows containing outliers
# numerical_df = numerical_df[~outliers.any(axis=1)]

# Fill NaN values with a suitable method (e.g., mean, median, or interpolation)
numerical_df.fillna(numerical_df.mean(), inplace=True)

# Print the updated dataframe
numerical_df.head(5)
# Out:
#    Total Plan Duration (minutes)  Calories Burned (Plan)  Height (cm)  Age  \
# 0                             35                   544.0          157   24
# 1                             50                   544.0          193   50
# 2                             70                   744.0          199   45
# 3                             60                   900.0          150   49
# 4                             60                   768.0          178   51
#
#    Weight (kg)        BMI  Knee Pain  Back Pain  Diabetes  Heart Disease  \
# 0           56  22.857097          0          1         0              0
# 1           99  26.632088          0          1         0              0
# 2          117  29.749211          0          1         1              0
# 3           43  19.528223          0          1         1              0
# 4           86  27.382191          1          1         0              0
#
#    Hypertension
# 0             0
# 1             0
# 2             0
# ...

# %%
sns.boxplot(data=numerical_df, orient="h")
plt.xlabel("Value")
plt.ylabel("Frequency")
#plt.title("ID")
plt.tight_layout()
plt.show()

# %%
df.to_csv(os.path.join('data', 'workout', 'Workout_Data1.csv'))
